# %% [markdown]
# # Introduction

# %% [markdown]
# Ce notebook fait suite au notebook 1 qui nous a permis de sélectionner les datasets les plus appropriés à notre tâches de classification et aussi de mieux comprendre l'impact des divers hyper-paramètres sur une architecture classique comme LeNet.
#
# N'ayant pu atteindre un niveau de performance adéquat dans un temps raisonnable, nous allons cette fois nous pencher sur un modèle de transfer learning en utilisant une architecture **VGG16** avec les poids d'**imagenet**, un dataset d'images génériques.
#
# Nous allons procéder en trois temps:
#
#
# 1.   Effectuer un entraînement de test sur une portion limitée du dataset pour évaluer le choix ne nos hyper-paramètres initiaux.
# 2.   En se basant sur l'évaluation du premier test, lancer un entraînement sur les données complètes
# 3. Ré-entraîner les 4 dernières couches de VGG16 pour tenter d'ajuster au plus près les poids de la partie extraction de features du meilleur modèle de 1 et 2
# 4. Sélectionner le modèle le plus prometteur refaire des entraînements en tentant de résoudre les problèmes d'overfitting observés
# 5. Ré-entraîner les 4 dernières couches de VGG16 pour tenter d'ajuster au plus près les poids de la partie extraction de features du meilleur modèle de 4

# %% [markdown]
# # Initialisation

# %%
import sys
import os

if 'google.colab' in sys.modules:
    from google.colab import drive
    if not os.path.exists('/content/drive'):
      drive.mount('/content/drive/')
    # %cd drive/MyDrive/nov23_bds_rakuten
else:
    root_files = os.listdir()
    if not "requirements.txt" in root_files:
        print("The jupyter server root should be set to root of git project")
        print("If you're on vscode add the following to your settings.json file")
        print('"jupyter.notebookFileRoot": "${workspaceFolder}"')
# Out:
# Mounted at /content/drive/
# /content/drive/MyDrive/nov23_bds_rakuten

# %%
random_state = 42
output_dir = "output/data-modeling-images-3"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from pathlib import Path
import re
from tqdm import tqdm
import pickle as pickle

import zipfile

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score,accuracy_score,classification_report

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback,EarlyStopping, LearningRateScheduler
from tensorflow.keras import backend as K
import keras.saving

from keras.utils import to_categorical
from keras.models import load_model
from keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input

# %% [markdown]
# # Librairie de fonctions

# %% [markdown]
# On récupère ici les fonctions définies dans le notebook **data-modeling-images-1**.
#
# Bien que je préfère en général définir les fonctions au fur et à mesure de leur utilisation, la multiplication des stratégies que nous allons tester rend plus simple de les rassembler dans cette section. En les extrayant du déroulement de chaque stratégie, nous pourrons plus efficacement dupliquer et identifier leur trame commune.

# %% [markdown]
# ## Import des données

# %% [markdown]
# Commençons par définir une fonction **import_images** qui permet d'importer le jeu d'images que l'on souhaite utiliser.

# %%
def import_images(zip_path,dest_dir):
    image_path = dest_dir
    image_dir = Path(image_path)
    if image_dir.exists():
        print("images already imported from drive")
    else:
        print("extracting images from drive into colab's session storage... (about 1 min)")
        with zipfile.ZipFile(zip_path,"r") as images_zip:
            images_zip.extractall(image_path)
    image_path = image_path + "/images"
    return image_path

# %% [markdown]
# ## Rapport de modèle

# %% [markdown]
# Avant de commencer à créer notre modèle, nous allons nous occuper de comment on pourra comparer les différentes stratégies que nous allons tester.
#
# Nous allons créer un dataframe **df_reporting** qui contiendra les informations pertinentes sur notre stratégie de modélisation ainsi que ses résultats:
# * Un nom et un id de modèle
# * Les sources de données utilisées ainsi que la taille du subset de données.
# * Les hyper-paramètres du modèle
# * L'état en cours de l'entraînement ainsi que le nombre d'époques à atteindre
# * Les métriques de performance de l'entraînement, la validation et des tests.
#
# Au fur et à mesure de nos tests, on veillera à sauvegarder ce dataframe dans un fichier **model_reporting.csv**. Ce fichier nous assurera qu'on puisse reprendre nos tests là où ils se sont arrêtés en cas d'interruption. Dans ce cas, on veillera également à sauvegarder l'état des modèles ayant la meilleure performance, afin de compléter l'entraînement sur les époques manquantes.
#
# Plus tard, le fichier **model_reporting.csv** nous servira aussi à comparer les modèles de chaque notebook de modélisation. Pour cette raison, on va tenter d'être le plus complet possible dans les informations qu'on y met.

# %% [markdown]
# Ajoutons une fonction qui va créer le dataframe **df_reporting** en y ajoutant un modèle d'exemple.

# %%
def create_reporting_df(save=True):
  reporting_df = pd.DataFrame([{
      #model infos
      "model_id":int(0),
      "model_name":"Example model",

      #data sources
      "dataset_source": "output/data-exploration/X_train_pre.csv",
      "dataset_resampled": False,
      "image_dataset_source" : "data/images.zip",
      "image_dataset_zoomed" : False,
      "train_size": int(42458),

      #hyper parameters
      "image_size": int(300),
      "image_color_rgb": True,
      "batch_size":int(32),
      "image_data_generator_params": {"rescale":1./255,"shear_range":0.2,"zoom_range":0.2,"horizontal_flip":True},
      "start_lr": 0.001,
      "last_lr": 0.0001,
      "optimizer": "adam",

      #fit info
      "target_epochs": int(10),
      "last_epoch": int(6),
      "fit_complete": True,

      #metrics
      "f1_score": 0.42,
      "val_f1_score": 0.37,
      "test_f1_score": 0.35,
      "accuracy": 0.57,
      "val_accuracy": 0.39,
      "test_accuracy": 0.41,
      "loss": 1.567,
      "val_loss": 2.657,

      #other
      "remarks": "Ceci n'est pas un vrai modèle. C'est juste un exemple",
  }])

  reporting_df.set_index("model_id",inplace=True)
  if save:
    reporting_df.to_csv(output_dir+"/model_reporting.csv")
  return reporting_df

# %% [markdown]
# Ajoutons également une fonction qui va nous permettre de charger un **model_reporting_df** s'il existe.

# %%
def load_reporting_df():
  return pd.read_csv(output_dir+"/model_reporting.csv",index_col="model_id")

# %% [markdown]
# On a besoin d'une fonction pour ajouter une nouvelle ligne dans **reporting_df**.

# %%
def add_reporting_line(model_id:int,model_name:str,save:bool=True):
  reporting_df.loc[int(model_id),"model_name"] = str(model_name)
  if save:
    reporting_df.to_csv(output_dir+"/model_reporting.csv")

# %% [markdown]
# Ajoutons une fonction pour ajouter ou modifier des informations dans notre modèle. On veillera à ce que cette fonction sauvegarde automatiquement le dataframe dans **model_reporting.csv**. On a besoin de garder le maximum d'informations en cas d'interruption.

# %%
def update_reporting_line(model_id: int,d:dict={},save:bool=True):
  for key in d.keys():
        reporting_df.at[int(model_id), str(key)] = d.get(key)
  if save:
    reporting_df.to_csv(output_dir+"/model_reporting.csv")

# %% [markdown]
# Ajoutons une fonction **get_reporting_value** qui permette de récupérer une information stockée pour un modèle.

# %%
def get_reporting_value(model_id,key,default=None):
  try:
    value = reporting_df.at[model_id,key]
    if np.isnan(value):
      value=None
  except KeyError:
    value=None

  if value == None and default != None:
      value=default
  return value

# %% [markdown]
# ## Création du modèle

# %% [markdown]
# Ajoutons une fonction **build_model** qui va nous permettre de créer les différentes couches de notre architecture basé sur une combinaison entre:
# * **VGG16** avec les poids d'**imagenet** comme extracteur de features
# * Un réseau de neurone dense classique qui prend en entrée la sortie de **VGG16** et est chargé de la classification des features
#
# > Note: Pour le moment, on gèle les couches de **VGG16** pour empecher que les poids pré-claclulés d'**imagenet** ne soient modifiés lors de l'entrainenemt.

# %%
def build_model(input_shape,dropout_rate = 0.2):
    base_model = VGG16(weights='imagenet', include_top=False,input_shape=input_shape)
    for layer in base_model.layers:
      layer.trainable = False

    model = Sequential()
    model.add(base_model)
    model.add(GlobalAveragePooling2D())
    model.add(Dense(units=1024,activation="relu"))
    model.add(Dropout(rate=dropout_rate))
    model.add(Dense(units=512,activation="relu"))
    model.add(Dropout(rate=dropout_rate))
    model.add(Dense(units=27,activation="softmax"))

    return model

# %% [markdown]
# Nous allons également avoir besoin d'une métrique personnalisée **w_f1_score** qui permette de calculer le F1 Score pondéré. On veille à ajouter l'annotation **@keras.saving.register_keras_serializable** pour que Keras ne pose pas de problème lors du chargement du modèle.

# %%
def f1_score_sklearn(y_true, y_pred):
    y_true_classes = np.argmax(y_true, axis=1)
    y_pred_classes = np.argmax(y_pred, axis=1)
    return f1_score(y_true_classes, y_pred_classes, average='weighted')

@keras.saving.register_keras_serializable(name='w_f1_score')
def w_f1_score(y_true, y_pred):
    f1 = tf.py_function(f1_score_sklearn, (y_true, y_pred), tf.float64)
    return f1

# %% [markdown]
# ## Sauvegarde du modèle

# %% [markdown]
# Toujours en vue d'être résilient par rapport aux interruptions qui ont lieu régulièrement lors de la phase d'entraînement du modèle, créons des fonctions qui vont nous permettre de sauvegarder et restaurer un modèle Keras, afin de pouvoir reprendre l'entraînement s'il a été stoppé, ou même d'afficher les métriques d'un modèle dont l'entraînement est complet.

# %%
def load_saved_model(model_id):
  model_path = output_dir+("/model-%d.keras" % model_id)
  model_path_obj = Path(model_path)
  if model_path_obj.exists():
    print("Load previous model from",model_path)
    return load_model(model_path)
  else:
    print("No previous model found at",model_path)
    return None

# %%
def save_model(model_id,model):
  path = output_dir+("/model-%d.keras" % model_id)
  print("save model ",model_id,"to ",path)
  model.save(path)

# %% [markdown]
# Comme nous allons afficher des graphiques sur l'évolution des métriques pendant l'entraînement, il nous faut également des fonctions qui nous permettent de sauver, charger un historique

# %%
def load_training_history(model_id):
  path = output_dir+("/training_history_%d.pkl" % model_id)
  history = None
  if Path(path).exists():
    with open(path, "rb") as file:
      history = pickle.load(file)
  return history

# %%
def save_training_history(model_id,history):
  path = output_dir+("/training_history_%d.pkl" % model_id)
  with open(path, "wb") as file:
    pickle.dump(history,file)

# %% [markdown]
# Parcequ'un entraînement peut être fait en plusieurs fois, nous devons pouvoir concaténer un historique d'entraînement actuel avec le précédent sauvegardé.

# %%
def concat_training_histories(prev_history,actual_history):
  full_history = {}
  for key in actual_history:
    full_history[key]=np.concatenate((prev_history[key],actual_history[key]),axis=0)
  return full_history

# %%
def get_full_training_history(model_id,training_history):
  if training_history == None:
    history = load_training_history(model_id)
  else:
    prev_history = load_training_history(model_id)
    if prev_history != None:
      history = concat_training_histories(prev_history,training_history.history)
    else:
      history = training_history.history
  return history

# %% [markdown]
# ## Callbacks pour l'entraînement du modèle

# %% [markdown]
# La callback **LogBest** va nous permettre de sauvegarder l'état de l'entraînement et les métriques du modèle à la fin de chaque époque.
#
# Seules les meilleures métriques sont sauvegardées. Elles correspondent à la meilleure époque du modèle que nous sauvegardons également. Elles sont donc mises à jour au fur et à mesure de l'entraînement.

# %%
class LogBest(Callback):
    def __init__(self, model_id):
        super().__init__()
        self.model_id = model_id

    def on_epoch_end(self, epoch, logs=None):

        update_reporting_line(self.model_id,{
            'last_epoch': epoch +1, # Epochs are 0-indexed, so we add 1
            'last_lr': float(K.get_value(self.model.optimizer.learning_rate)),
        })

        if float(logs['val_w_f1_score']) <= float(get_reporting_value(self.model_id,"val_f1_score",0.0)):
          return
        print("\nFound better model with val_f1_score=%.2f" % float(logs['val_w_f1_score']))
        update_reporting_line(self.model_id,{
            "f1_score": logs['w_f1_score'],
            "val_f1_score": logs['val_w_f1_score'],
            "accuracy": logs['accuracy'],
            "val_accuracy": logs['val_accuracy'],
            "loss": logs['loss'],
            "val_loss": logs['val_loss'],
        })
        save_model(self.model_id,self.model)

# %% [markdown]
# Cette callback nous permet de stopper l'entraînement lorsque le F1 Score ne progresse plus.

# %%
early_stopping = EarlyStopping(
              monitor='val_w_f1_score',
              mode="max", #stop when f1 score is not increasing anymore
              patience=5,           # Number of epochs with no improvement
              min_delta=1e-2,       # Minimum change to qualify as an improvement
)

# %% [markdown]
# ## Évaluation du modèle

# %% [markdown]
# Ajoutons quelques fonctions qui vont nous faciliter l'affichage de graphiques et de matrices lors de la phase d'évaluation du modèle.

# %% [markdown]
# La fonction **plot_training_history** permet d'afficher l'évolution des différentes métriques en suivant le cours des époques de la phase d'entraînement.

# %%
def plot_training_history(history):
  x = range(1,len(history['accuracy']) + 1 )
  plt.figure(figsize=(12,5))
  plt.subplot(121)
  plt.plot(x,history['val_accuracy'],label="val_accuracy")
  plt.plot(x,history['accuracy'],label="accuracy")
  plt.plot(x,history['val_w_f1_score'],label="val_f1_score")
  plt.plot(x,history['w_f1_score'],label="f1_score")
  plt.xticks(x)
  plt.xlabel("Epoch")
  plt.ylabel("Score")
  plt.title("Accuracy/f1 evolution during training")
  plt.legend()

  plt.subplot(122)
  plt.plot(x,history['val_loss'],label="val_loss")
  plt.plot(x,history['loss'],label="loss")
  plt.xticks(x)
  plt.xlabel("Epoch")
  plt.ylabel("Loss")
  plt.title("Loss evolution during training")
  plt.legend()

  plt.show()

# %% [markdown]
# Ici, on récupère du notebook **data-exploration** les labels correspondant aux classes, pour donner plus de lisibilité lors de l'évaluation.

# %%
prdcodetype2label = {
    10 : "Livre occasion",
    40 : "Jeu vidéo, accessoire tech",
    50 : "Accessoire Console",
    60 : "Console de jeu",
    1140 : "Figurine",
    1160 : "Carte Collection",
    1180 : "Jeu Plateau",
    1280 : "Jouet enfant,déguisement",
    1281 : "Jeu société",
    1300 : "Jouet tech",
    1301 : "Jeu intérieur,chaussettes",
    1302 : "Jeu extérieur,vêtement",
    1320 : "Bébé",
    1560 : "Mobilier intérieur",
    1920 : "Chambre",
    1940 : "Cuisine",
    2060 : "Décoration intérieure",
    2220 : "Animal",
    2280 : "Revues,journaux",
    2403 : "Magazines,livres,BDs",
    2462 : "Jeu occasion",
    2522 : "Bureautique,papeterie",
    2582 : "Mobilier extérieur",
    2583 : "Piscine",
    2585 : "Bricolage",
    2705 : "Livre neuf",
    2905 : "Jeu PC",
}

# %% [markdown]
# Enfin, ajoutons une fonction **plot_confusion_matrix** qui nous permette d'afficher la matrice de confusion de manière lisible.

# %%
def plot_confusion_matrix(cm):
  plt.figure(figsize=(15, 8))
  sns.set(font_scale=0.8)
  classes = [(str(c) +": "+ prdcodetype2label[int(c)]) for c in classes_keras]
  sns.heatmap(cm, annot=True, cbar=True, square=False,fmt='g'
              ,xticklabels=classes,yticklabels=classes)
  plt.xlabel('Prédit')
  plt.ylabel('Réel')
  plt.title('Matrice de confusion')
  plt.show()

# %% [markdown]
# # Modélisation 1

# %% [markdown]
# Cette première modélisation va servir d'entrainement de test dont les resulats de l'évaluation nous servirons par la suite pour ajuster nos hyper-paramètres à des valeurs adéquates. Nous allons partir sur les bases suivantes:
# * Dataset d'image zoomées
# * Dataset ré-équilibré
# * **batch_size**=64
# * **image_size**=224 pour correspondre au format des images avec lesquelles **VGG16** a été entrainé
# * Un optimiseur **Adam** avec un learning rate de départ de 0.001

# %%
model_id = 311

# %% [markdown]
# ## Import des données

# %% [markdown]
# On importe donc les images zoomées qui ont été produites par le notebook **data_preprocessing_images**

# %%
image_path = import_images("output/data-preprocessing-images/images_pre.zip","/tmp/rakuten-images-2")
# Out:
# extracting images from drive into colab's session storage... (about 1 min)

# %% [markdown]
# On charge maintenant le csv des données ré-équilibrées par le notebook **data_preprocessing_resampling**. Ce notebook étant executé à partir des données en sortie de **data_preprocessing_images**, il contient également la colonne **imagefile**.
#
# Nous n'aurons pas besoin de refaire le split des données d'entrainement, **data_preprocessing_resampling** s'en étant déjà chargé. Nous avons juste à charger les trois fichiers qui constituent sa sortie:
# * **df_train.csv**: L'ensemble d'entrainement
# * **df_val.csv**: L'ensemble de validation
# * **df_test.csv**: L'ensemble de test

# %%
df_train = pd.read_csv("output/data-preprocessing-resampling/df_train.csv",index_col=0)
df_val = pd.read_csv("output/data-preprocessing-resampling/df_val.csv",index_col=0)
df_test = pd.read_csv("output/data-preprocessing-resampling/df_test.csv",index_col=0)
df_train.head()
# Out:
#     productid     imageid                                               text  \
# 0   131641431   885888766  Jesus - Cahiers Du Libre Avenir - Prêtre autre...
# 1   745789761  1304710852  The Inglorious Arts Of Peace: Exhibitions In C...
# 2   651353882  1033554185  Lecons De Sciences - Cours Superieur - Premier...
# 3  4043473264  1306457352                 Generations Of Women Historians -
# 4   679913105  1034656535       Oeuvres Dramatiques De F. Schiller Tome 6 -
#
#   lang                                            text_fr  \
# 0   fr  Jesus - Cahiers Du Libre Avenir - Prêtre autre...
# 1   en  Les arts de la paix sans gloire: expositions d...
# 2   fr  Lecons De Sciences - Cours Superieur - Premier...
# 3   en                 Générations de femmes historiens -
# 4   fr       Oeuvres Dramatiques De F. Schiller Tome 6 -
#
#                                     imagefile  prdtypecode
# 0    10/image_885888766_product_131641431.jpg           10
# 1   10/image_1304710852_product_745789761.jpg           10
# 2   10/image_1033554185_product_651353882.jpg           10
# 3  10/image_1306457352_product_4043473264.jpg           10
# 4   10/image_1034656535_product_679913105.jpg           10

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# On sépare les variables explicatives de la cible.

# %%
X_train = df_train.drop("prdtypecode",axis=1)
y_train = df_train["prdtypecode"]

X_validation = df_val.drop("prdtypecode",axis=1)
y_validation = df_val["prdtypecode"]

X_test = df_test.drop("prdtypecode",axis=1)
y_test = df_test["prdtypecode"]

# %% [markdown]
# On applique un traitement similaire à la modélisation 1.3 du premier notebook, mais en modifiant **target_train_size** pour ne garder que 20 % des données d'entraînement.

# %%
target_train_size = int(len(X_train)*0.2)
print("Target train size is",target_train_size)
train_split_rate = (len(X_train) - target_train_size) / len(X_train)
X_train, X_none, y_train, y_none = train_test_split(X_train,y_train,test_size=train_split_rate,random_state = random_state,
                                                    shuffle=True,stratify=y_train)
print("X_train length is now",len(X_train))
# Out:
# Target train size is 21913
# X_train length is now 21913

# %% [markdown]
# Confirmons que les classes sont toujours équilibrées après la réduction.

# %%
y_train.value_counts()
# Out:
# 1160    812
# 1940    812
# 2060    812
# 2582    812
# 2220    812
# 50      812
# 1560    812
# 40      812
# 1300    812
# 1281    812
# 2585    812
# 1140    812
# 1320    812
# 2522    812
# 1302    812
# 10      812
# 2280    811
# 2705    811
# 1180    811
# 1301    811
# 1920    811
# 2403    811
# 60      811
# 2583    811
# 2462    811
# 2905    811
# 1280    811
# Name: prdtypecode, dtype: int64

# %% [markdown]
# C'est bien le cas

# %% [markdown]
# On va laisser les set de test et de validation inchangés car ils sont déjà calibré à 10% des données

# %% [markdown]
# ## Initialisation du rapport de modèle

# %% [markdown]
# Si un fichier **model_reporting.csv** existe, on le charge. Autrement, on en crée un nouveau.

# %%
Path(output_dir).mkdir(parents=True, exist_ok=True)
try:
  reporting_df = load_reporting_df()
  print("loaded ",output_dir+"/model_reporting.csv")
except FileNotFoundError:
  reporting_df = create_reporting_df()
  print(output_dir+"/model_reporting.csv","not found. creating one")
# Out:
# loaded  output/data-modeling-images-3/model_reporting.csv

# %%
reporting_df.head()
# Out:
#              model_name                                     dataset_source  \
# model_id
# 0         Example model            output/data-exploration/X_train_pre.csv
# 311          Modèle 3.1  output/data-preprocessing-resampling/df_{train...
# 321          Modèle 3.2  output/data-preprocessing-resampling/df_{train...
# 331          Modèle 3.3  output/data-preprocessing-resampling/df_{train...
# 341        Modèle 3.4.1  output/data-preprocessing-resampling/df_{train...
#
#           dataset_resampled                             image_dataset_source  \
# model_id
# 0                     False                                  data/images.zip
# 311                    True  output/data-preprocessing-images/images_pre.zip
# 321                    True  output/data-preprocessing-images/images_pre.zip
# 331                    True  output/data-preprocessing-images/images_pre.zip
# 341                    True  output/data-preprocessing-images/images_pre.zip
#
#           image_dataset_zoomed  train_size  image_size  image_color_rgb  \
# model_id
# 0                        False     42458.0       300.0             True
# 311                       True     21913.0       224.0             True
# 321                       True    109566.0       224.0             True
# 331                       True    109566.0       224.0             True
# 341                       True    109566.0       224.0             True
#
#           batch_size                        image_data_generator_params  ...  \
# model_id                                                                 ...
# 0               32.0  {'rescale': 0.00392156862745098, 'shear_range'...  ...
# 311             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 321             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 331             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 341             32.0  {'preprocessing_function': 'preprocess_input',...  ...
#
#           fit_complete  f1_score val_f1_score  test_f1_score  accuracy  \
# model_id
# 0                 True  0.420000     0.370000       0.350000  0.570000
# 311               True  0.552243     0.520430       0.514401  0.558103
# 321               True  0.665658     0.561671       0.556558  0.669275
# 331               True  0.739655     0.601403       0.601500  0.742927
# 341               True  0.415287     0.483479       0.492511  0.421559
#
#           val_accuracy  test_accuracy      loss  val_loss  \
# model_id
# 0             0.390000       0.410000  1.567000  2.657000
# 311           0.516927       0.515191  1.433475  1.707712
# 321           0.552675       0.552991  1.067026  1.611750
# 331           0.597656       0.598681  0.806426  1.479870
# 341           0.472641       0.480217  1.990221  1.791615
#
#                                                     remarks
# model_id
# 0         Ceci n'est pas un vrai modèle. C'est juste un ...
# 311                                                     NaN
# 321                                                     NaN
# 331       4 dernière couches de VGG16 repassées à traina...
# 341         early_stopping plus agressif + dropout_rate=0.5
#
# [5 rows x 25 columns]

# %% [markdown]
# Ajoutons une ligne correspondant à notre modèle et commençons à renseigner ses informations.

# %%
add_reporting_line(model_id,"Modèle 3.1")

# %% [markdown]
# On peut déjà renseigner les informations sur les données sources qu'on utilise.

# %%
update_reporting_line(model_id,{
    "dataset_source": "output/data-preprocessing-resampling/df_{train,val,test}.zip",
    "dataset_resampled": True,
    "image_dataset_source" : "output/data-preprocessing-images/images_pre.zip",
    "image_dataset_zoomed" : True,
    "train_size": len(X_train),
})

# %% [markdown]
# ## Générateurs d'images

# %% [markdown]
# Dans cette section, nous allons créer les générateurs qui vont fournir au modèle les images.

# %% [markdown]
# Commençons par créer une liste ordonnée des classes que l'on va fournir aux générateurs. Plus tard, cette liste nous servira à retrouver les classes correspondant aux prédictions, car la méthode **predict** de Keras retourne une matrice dont les colonnes correspondent aux classes dans l'ordre auquel on les a fournies.

# %%
classes_keras = list(np.sort(np.array(df_train["prdtypecode"].unique(),dtype="str")))

# %% [markdown]
# Pour le générateur d'entraînement, on réutilise les paramètres de transformations du notebook **data-modeling-images-1** car ils semblent avoir bien fonctionné (on n'a pas observé d'overfitting lors de nos tests).
#
# On va toutefois modifier **target_img_size** comme annoncé dans le préambule de cette section.
#
# Enfin, nous enlevons le paramètre `rescale=1./255` qu'on remplace par `preprocessing_function=ts.keras.applications.vgg16.preprocess_input`. C'est **preprocess_input** qui se charge de convertir le format d'image en un format compatible avec **VGG16**.

# %%
train_data_generator = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=5,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

update_reporting_line(model_id, {
    "image_data_generator_params" : {
      "preprocessing_function":"preprocess_input",
      "rotation_range":20,
      "width_shift_range":0.2,
      "height_shift_range":0.2,
      "shear_range":5,
      "zoom_range":0.1,
      "horizontal_flip":True,
      "vertical_flip":False,
      "fill_mode":'nearest'
      }
})
batch_size=64
target_img_size = (224,224,3)
color_mode = "rgb"

update_reporting_line(model_id, {
    "batch_size":batch_size,
    "image_size": target_img_size[0],
    "image_color_rgb": True
})

train_generator = train_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_train['imagefile'],"prdtypecode": y_train.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras
)
# Out:
# Found 21913 validated image filenames belonging to 27 classes.

# %%
validation_data_generator = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

validation_generator = validation_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_validation['imagefile'],"prdtypecode": y_validation.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras
)
# Out:
# Found 8492 validated image filenames belonging to 27 classes.

# %%
test_data_generator = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

test_generator = test_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_test['imagefile'],"prdtypecode": y_test.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras,
    shuffle=False
)
# Out:
# Found 8492 validated image filenames belonging to 27 classes.

# %% [markdown]
# ## Création du modèle

# %% [markdown]
# S'il n'y a pas encore de modèle enregistré, on le construit puis on le compile en veillant à passer notre métrique **w_f1_score** personnalisée. On choisit d'utiliser le taux d'apprentissage par défaut (0.001).

# %%
model = load_saved_model(model_id)
start_lr = 0.001
if model == None:
  print("build model")
  model = build_model(target_img_size)
  model.compile(
      optimizer=Adam(learning_rate=start_lr),
      loss='categorical_crossentropy',
      metrics=['accuracy',w_f1_score]
  )
  update_reporting_line(model_id,{
      "start_lr": start_lr,
      "optimizer": "adam",
  })

model.summary()
# Out:
# Load previous model from output/data-modeling-images-3/model-311.keras
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 27)                13851
#
# =================================================================
# Total params: 15778651 (60.19 MB)
# Trainable params: 1063963 (4.06 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %% [markdown]
# ## Entraînement du modèle

# %% [markdown]
# On procède à l'entraînement du modèle uniquement si le rapport nous indique que son entraînement n'est pas fini (colonne **fit_complete**).
#
# Dans le cas de la reprise d'un entraînement interrompu, on reprend l'entraînement pour le nombre d'époques qu'il reste à accomplir pour atteindre le nombre d'époques visé (**target_epochs**).
#
# Une fois l'entraînement terminé, on passe **fit_complete** à **True**.
#
# Les métriques sur la progression de l'entraînement ainsi que les meilleurs modèles sont récoltées et enregistrées dans la callback **LogBest**.
#
# Pour ce run de test, nous limitons le nombre d'époques à 10.

# %%
target_epochs = 10
if not get_reporting_value(model_id,"fit_complete",False):
  update_reporting_line(model_id,{
      "target_epochs": target_epochs
  })
  training_history = model.fit(
      train_generator,
      validation_data=validation_generator,
      steps_per_epoch=train_generator.samples // batch_size,
      validation_steps = validation_generator.samples // batch_size,
      epochs=target_epochs - int(get_reporting_value(model_id,"last_epoch",0)),
      verbose=1,
      callbacks=[LogBest(model_id),early_stopping]
  )
  update_reporting_line(model_id,{"fit_complete":True})
else:
  print("No need to train model")
  training_history = None
# Out:
# No need to train model

# %% [markdown]
# ## Évaluation du modèle

# %% [markdown]
# Si un entraînement a eu lieu au cours de cette exécution du notebook, on recharge le meilleur modèle qu'on a trouvé.

# %%
if training_history != None:
  #if fit wad called, make sure to load best saved model, otherwise it's already loaded
  model = load_saved_model(model_id)

# %% [markdown]
# On teste le modèle sur l'ensemble de test.

# %%
test_pred = model.predict(test_generator,verbose=1)
# Out:
# 133/133 [==============================] - 77s 486ms/step

# %% [markdown]
# On doit convertir le résultat de **predict** depuis le format renvoyé par Keras, qui est une matrice de probabilités avec les classes en colonnes et les observations du jeu de test en lignes, en un tableau à 1 dimension contenant les classes prédites pour chaque observation.
#
# Pour cela, on extrait pour chaque observation l'index de la probabilité maximale de prédiction. On utilise ensuite cet index pour retrouver la classe correspondante dans **classes_keras**, la liste des classes telle qu'on la fournit à Keras.

# %%
test_pred_class = np.argmax(test_pred,axis=1)
test_pred_class = [classes_keras[c] for c in test_pred_class]

# %% [markdown]
# À partir des classes prédites et des observations réelles, on calcule le score F1 ainsi que l'accuracy de notre modèle, toujours sur le jeu de test.
#
# On enregistre ces informations dans le rapport.

# %%
f1_weighted = f1_score(y_test.astype("str"),test_pred_class,average="weighted")
accuracy = accuracy_score(y_test.astype("str"),test_pred_class)
update_reporting_line(model_id,{
    "test_f1_score":f1_weighted,
    "test_accuracy":accuracy
})

print("f1_score on test dataset=%.4f" % f1_weighted)
print("accuracy on test dataset=%.4f" % accuracy)
# Out:
# f1_score on test dataset=0.5144
# accuracy on test dataset=0.5152

# %% [markdown]
# On constate un f1_score de **0.51**, c'est le premier score qui tombe dans l'intervalle visé de 0.5-0.6 !
#
# Un entraînement sur seulement 20% de l'ensemble d'entraînement est suffisant pour passer le test. On pourrait être tenté de s'arrêter là, mais n'oublions pas que le but de ce classifieur est d'opérer sur des données nouvelles. Il gagnera donc à être entraîné sur la totalité des données.

# %% [markdown]
# Récupérons l'historique d'entraînement complet grâce à **get_full_training_history** qu'on va enregistrer. Puis, affichons deux graphiques :
#
# * L'évolution de l'**accuracy** et du **score F1** en fonction des époques.
# * L'évolution des indicateurs de perte **loss** et **val_loss**.

# %%
history = get_full_training_history(model_id,training_history)
if history != None:
  save_training_history(model_id,history)
  #to avoid concat of same history when re-executing this cell
  training_history = None
  plot_training_history(history)

# %% [markdown]
# Dès l'époque 3, on commence à voir des signes d'overfitting car *loss* passe en dessous de **val_loss**.
#
# Cela ne signifie pas que les métriques sur l'ensemble de validation cessent de progresser, puisqu'elles atteignent leur niveau optimal vers l'époque 6. Il est toutefois notable qu'elles progressent beaucoup moins vite après l'époque 3 et qu'elles finissent même par stagner à partir de l'époque 6.
#
# On pourrait être tenté par la suite d'augmenter les transformations d'images, mais il est probable que ça n'aide pas vraiment, les couches de VGG16 étant gelées. On peut penser que l'overfitting ne provient pas de la partie extraction de features de notre CNN, mais plutôt des couches de classification qu'on a ajoutées après.
#
# Ne nous attardons pas trop là-dessus pour le moment, car le prochain test utilisera toutes les données, ce qui pourrait résoudre de fait ce souci d'overfitting.

# %%
print(classification_report(y_test.astype("str"),test_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#           10       0.38      0.37      0.38       311
#         1140       0.51      0.56      0.53       267
#         1160       0.73      0.88      0.80       396
#         1180       0.18      0.39      0.25        76
#         1280       0.50      0.23      0.31       487
#         1281       0.33      0.22      0.27       207
#         1300       0.51      0.67      0.58       505
#         1301       0.37      0.59      0.45        81
#         1302       0.33      0.35      0.34       249
#         1320       0.40      0.38      0.39       324
#         1560       0.47      0.52      0.50       507
#         1920       0.72      0.79      0.75       431
#         1940       0.39      0.73      0.50        81
#         2060       0.51      0.34      0.41       499
#         2220       0.25      0.43      0.31        82
#         2280       0.67      0.57      0.62       476
#         2403       0.61      0.44      0.51       477
#         2462       0.45      0.42      0.43       142
#         2522       0.61      0.61      0.61       499
#         2582       0.37      0.43      0.40       259
#         2583       0.83      0.61      0.70      1021
#         2585       0.25      0.28      0.26       250
#         2705       0.42      0.70      0.53       276
#         2905       0.40      0.69      0.50        87
#           40       0.54      0.41      0.47       251
#           50       0.25      0.32      0.28       168
#           60       0.38      0.67      0.48        83
#
#     accuracy                           0.52      8492
#    macro avg       0.46      0.50      0.47      8492
# weighted avg       0.54      0.52      0.51      8492

# %% [markdown]
# Par rapport au notebook **data-modeling-images**, on ne constate plus de classes avec des f1-score qui frôlent le zéro, c'est rassurant.
#
# Au contraire, certaines classes ont des f1-scores plutôt élevés, comme la classe **1160** avec 0.80 ou encore les classes **1920** et **2583** avec respectivement 0.75 et 0.70.

# %% [markdown]
# Affichons la matrice de confusion sous forme de heatmap pour plus de lisibilité.

# %%
cm = pd.crosstab(y_test.astype("str"),test_pred_class,rownames=["réel"],colnames=["prédit"])
plot_confusion_matrix(np.array(cm))

# %% [markdown]
# On voit enfin une diagonale de vrais positifs qui semble complète.
#
# Quelques faux positifs sont plutôt élevés, mais ils semblent être des confusions assez logiques. Par exemple :
# - Livre neuf -> livre occasion
# - Jouets tech -> Jouets enfant déguisement

# %% [markdown]
# ## Résumé

# %% [markdown]
# Nous avons atteint la fin de l'évaluation de cette modélisation. Affichons le rapport du modèle.

# %%
reporting_df.loc[model_id].T
# Out:
# model_name                                                            Modèle 3.1
# dataset_source                 output/data-preprocessing-resampling/df_{train...
# dataset_resampled                                                           True
# image_dataset_source             output/data-preprocessing-images/images_pre.zip
# image_dataset_zoomed                                                        True
# train_size                                                               21913.0
# image_size                                                                 224.0
# image_color_rgb                                                             True
# batch_size                                                                  64.0
# image_data_generator_params    {'preprocessing_function': 'preprocess_input',...
# start_lr                                                                   0.001
# last_lr                                                                    0.001
# optimizer                                                                   adam
# target_epochs                                                               10.0
# last_epoch                                                                  10.0
# fit_complete                                                                True
# f1_score                                                                0.552243
# val_f1_score                                                             0.52043
# test_f1_score                                                           0.514401
# accuracy                                                                0.558103
# val_accuracy                                                            0.516927
# test_accuracy                                                           0.515191
# loss                                                                    1.433475
# val_loss                                                                1.707712
# remarks                                                                      NaN
# Name: 311, dtype: object

# %% [markdown]
# On mesure clairement les bénéfices de l'utilisation de **VGG16/imagenet** dans cette première modélisation.

# %% [markdown]
# # Modélisation 2

# %% [markdown]
# Nous avons vu que les paramètres choisis précédemment ont semblé plutôt bien fonctionner sur un dataset limité à 20% des données. On va donc les réutiliser à plus grande échelle en entraînant le modèle sur toutes les données.

# %%
model_id = 321

# %% [markdown]
# ## Import des données

# %% [markdown]
# On réutilise les données importées dans la modélisation 1

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# On refait la séparation des variables explicatives de la cible en utilisant cette fois la totalité du dataset.

# %%
X_train = df_train.drop("prdtypecode",axis=1)
y_train = df_train["prdtypecode"]

X_validation = df_val.drop("prdtypecode",axis=1)
y_validation = df_val["prdtypecode"]

X_test = df_test.drop("prdtypecode",axis=1)
y_test = df_test["prdtypecode"]

# %% [markdown]
# Confirmons que les classes sont bien équilibrées

# %%
y_train.value_counts()
# Out:
# 10      4058
# 1920    4058
# 2705    4058
# 2585    4058
# 2583    4058
# 2582    4058
# 2522    4058
# 2462    4058
# 2403    4058
# 2280    4058
# 2220    4058
# 2060    4058
# 1940    4058
# 1560    4058
# 40      4058
# 1320    4058
# 1302    4058
# 1301    4058
# 1300    4058
# 1281    4058
# 1280    4058
# 1180    4058
# 1160    4058
# 1140    4058
# 60      4058
# 50      4058
# 2905    4058
# Name: prdtypecode, dtype: int64

# %% [markdown]
# C'est bien le cas

# %% [markdown]
# ## Initialisation du rapport de modèle

# %% [markdown]
# Si un fichier **model_reporting.csv** existe, on le charge. Autrement, on en crée un nouveau.

# %%
Path(output_dir).mkdir(parents=True, exist_ok=True)
try:
  reporting_df = load_reporting_df()
  print("loaded ",output_dir+"/model_reporting.csv")
except FileNotFoundError:
  reporting_df = create_reporting_df()
  print(output_dir+"/model_reporting.csv","not found. creating one")
# Out:
# loaded  output/data-modeling-images-3/model_reporting.csv

# %%
reporting_df.head()
# Out:
#              model_name                                     dataset_source  \
# model_id
# 0         Example model            output/data-exploration/X_train_pre.csv
# 311          Modèle 3.1  output/data-preprocessing-resampling/df_{train...
# 321          Modèle 3.2  output/data-preprocessing-resampling/df_{train...
# 331          Modèle 3.3  output/data-preprocessing-resampling/df_{train...
# 341        Modèle 3.4.1  output/data-preprocessing-resampling/df_{train...
#
#           dataset_resampled                             image_dataset_source  \
# model_id
# 0                     False                                  data/images.zip
# 311                    True  output/data-preprocessing-images/images_pre.zip
# 321                    True  output/data-preprocessing-images/images_pre.zip
# 331                    True  output/data-preprocessing-images/images_pre.zip
# 341                    True  output/data-preprocessing-images/images_pre.zip
#
#           image_dataset_zoomed  train_size  image_size  image_color_rgb  \
# model_id
# 0                        False     42458.0       300.0             True
# 311                       True     21913.0       224.0             True
# 321                       True    109566.0       224.0             True
# 331                       True    109566.0       224.0             True
# 341                       True    109566.0       224.0             True
#
#           batch_size                        image_data_generator_params  ...  \
# model_id                                                                 ...
# 0               32.0  {'rescale': 0.00392156862745098, 'shear_range'...  ...
# 311             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 321             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 331             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 341             32.0  {'preprocessing_function': 'preprocess_input',...  ...
#
#           fit_complete  f1_score val_f1_score  test_f1_score  accuracy  \
# model_id
# 0                 True  0.420000     0.370000       0.350000  0.570000
# 311               True  0.552243     0.520430       0.514401  0.558103
# 321               True  0.665658     0.561671       0.556558  0.669275
# 331               True  0.739655     0.601403       0.601500  0.742927
# 341               True  0.415287     0.483479       0.492511  0.421559
#
#           val_accuracy  test_accuracy      loss  val_loss  \
# model_id
# 0             0.390000       0.410000  1.567000  2.657000
# 311           0.516927       0.515191  1.433475  1.707712
# 321           0.552675       0.552991  1.067026  1.611750
# 331           0.597656       0.598681  0.806426  1.479870
# 341           0.472641       0.480217  1.990221  1.791615
#
#                                                     remarks
# model_id
# 0         Ceci n'est pas un vrai modèle. C'est juste un ...
# 311                                                     NaN
# 321                                                     NaN
# 331       4 dernière couches de VGG16 repassées à traina...
# 341         early_stopping plus agressif + dropout_rate=0.5
#
# [5 rows x 25 columns]

# %% [markdown]
# Ajoutons une ligne correspondant à notre modèle et commençons à renseigner ses informations.

# %%
add_reporting_line(model_id,"Modèle 3.2")

# %% [markdown]
# On peut déjà renseigner les informations sur les données sources qu'on utilise.

# %%
update_reporting_line(model_id,{
    "dataset_source": "output/data-preprocessing-resampling/df_{train,val,test}.zip",
    "dataset_resampled": True,
    "image_dataset_source" : "output/data-preprocessing-images/images_pre.zip",
    "image_dataset_zoomed" : True,
    "train_size": len(X_train),
})

# %% [markdown]
# ## Générateurs d'images

# %% [markdown]
# Dans cette section, nous allons créer les générateurs qui vont fournir au modèle les images.

# %% [markdown]
# Commençons par créer une liste ordonnée des classes que l'on va fournir aux générateurs. Plus tard, cette liste nous servira à retrouver les classes correspondant aux prédictions, car la méthode **predict** de Keras retourne une matrice dont les colonnes correspondent aux classes dans l'ordre auquel on les a fournies.

# %%
classes_keras = list(np.sort(np.array(df_train["prdtypecode"].unique(),dtype="str")))

# %% [markdown]
# On réutilise les mêmes paramètres que lors de la modélisation 1

# %%
train_data_generator = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=5,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

update_reporting_line(model_id, {
    "image_data_generator_params" : {
      "preprocessing_function":"preprocess_input",
      "rotation_range":20,
      "width_shift_range":0.2,
      "height_shift_range":0.2,
      "shear_range":5,
      "zoom_range":0.1,
      "horizontal_flip":True,
      "vertical_flip":False,
      "fill_mode":'nearest'
      }
})
batch_size=64
target_img_size = (224,224,3)
color_mode = "rgb"

update_reporting_line(model_id, {
    "batch_size":batch_size,
    "image_size": target_img_size[0],
    "image_color_rgb": True
})

train_generator = train_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_train['imagefile'],"prdtypecode": y_train.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras
)
# Out:
# Found 109566 validated image filenames belonging to 27 classes.

# %%
validation_data_generator = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

validation_generator = validation_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_validation['imagefile'],"prdtypecode": y_validation.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras
)
# Out:
# Found 8492 validated image filenames belonging to 27 classes.

# %%
test_data_generator = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

test_generator = test_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_test['imagefile'],"prdtypecode": y_test.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras,
    shuffle=False
)
# Out:
# Found 8492 validated image filenames belonging to 27 classes.

# %% [markdown]
# ## Création du modèle

# %% [markdown]
# S'il n'y a pas encore de modèle enregistré, on le construit puis on le compile en veillant à passer notre métrique **w_f1_score** personnalisée. On choisit d'utiliser le taux d'apprentissage par défaut (0.001).

# %%
model = load_saved_model(model_id)
start_lr = 0.001
if model == None:
  print("build model")
  model = build_model(target_img_size)
  model.compile(
      optimizer=Adam(learning_rate=start_lr),
      loss='categorical_crossentropy',
      metrics=['accuracy',w_f1_score]
  )
  update_reporting_line(model_id,{
      "start_lr": start_lr,
      "optimizer": "adam",
  })

model.summary()
# Out:
# Load previous model from output/data-modeling-images-3/model-321.keras
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 27)                13851
#
# =================================================================
# Total params: 15778651 (60.19 MB)
# Trainable params: 1063963 (4.06 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %% [markdown]
# ## Entraînement du modèle

# %% [markdown]
# On procède à l'entraînement du modèle uniquement si le rapport nous indique que son entraînement n'est pas fini (colonne **fit_complete**).
#
# Dans le cas de la reprise d'un entraînement interrompu, on reprend l'entraînement pour le nombre d'époques qu'il reste à accomplir pour atteindre le nombre d'époques visé (**target_epochs**) qu'on passe cette fois à 20.
#
# Une fois l'entraînement terminé, on passe **fit_complete** à **True**.
#
# Les métriques sur la progression de l'entraînement ainsi que les meilleurs modèles sont récoltées et enregistrées dans la callback **LogBest**.

# %%
target_epochs = 20
if not get_reporting_value(model_id,"fit_complete",False):
  update_reporting_line(model_id,{
      "target_epochs": target_epochs
  })
  training_history = model.fit(
      train_generator,
      validation_data=validation_generator,
      steps_per_epoch=train_generator.samples // batch_size,
      validation_steps = validation_generator.samples // batch_size,
      epochs=target_epochs - int(get_reporting_value(model_id,"last_epoch",0)),
      verbose=1,
      callbacks=[LogBest(model_id),early_stopping]
  )
  update_reporting_line(model_id,{"fit_complete":True})
else:
  print("No need to train model")
  training_history = None
# Out:
# No need to train model

# %% [markdown]
# ## Évaluation du modèle

# %% [markdown]
# Si un entraînement a eu lieu au cours de cette exécution du notebook, on recharge le meilleur modèle qu'on a trouvé.

# %%
if training_history != None:
  #if fit wad called, make sure to load best saved model, otherwise it's already loaded
  model = load_saved_model(model_id)

# %% [markdown]
# On teste le modèle sur l'ensemble de test.

# %%
test_pred = model.predict(test_generator,verbose=1)
# Out:
# 133/133 [==============================] - 51s 382ms/step

# %% [markdown]
# On doit convertir le résultat de **predict** depuis le format renvoyé par Keras, qui est une matrice de probabilités avec les classes en colonnes et les observations du jeu de test en lignes, en un tableau à 1 dimension contenant les classes prédites pour chaque observation.
#
# Pour cela, on extrait pour chaque observation l'index de la probabilité maximale de prédiction. On utilise ensuite cet index pour retrouver la classe correspondante dans **classes_keras**, la liste des classes telle qu'on la fournit à Keras.

# %%
test_pred_class = np.argmax(test_pred,axis=1)
test_pred_class = [classes_keras[c] for c in test_pred_class]

# %% [markdown]
# À partir des classes prédites et des observations réelles, on calcule le score F1 ainsi que l'accuracy de notre modèle, toujours sur le jeu de test.
#
# On enregistre ces informations dans le rapport.

# %%
f1_weighted = f1_score(y_test.astype("str"),test_pred_class,average="weighted")
accuracy = accuracy_score(y_test.astype("str"),test_pred_class)
update_reporting_line(model_id,{
    "test_f1_score":f1_weighted,
    "test_accuracy":accuracy
})

print("f1_score on test dataset=%.4f" % f1_weighted)
print("accuracy on test dataset=%.4f" % accuracy)
# Out:
# f1_score on test dataset=0.5566
# accuracy on test dataset=0.5530

# %% [markdown]
# On atteint un nouveau maximum pour le **f1-score** et l'**accuracy** avec 0.56 et 0.55 !

# %% [markdown]
# Récupérons l'historique d'entraînement complet grâce à **get_full_training_history** qu'on va enregistrer. Puis, affichons deux graphiques :
#
# * L'évolution de l'**accuracy** et du **f1-score** en fonction des époques.
# * L'évolution des indicateurs de perte **loss** et **val_loss**.

# %%
history = get_full_training_history(model_id,training_history)
if history != None:
  save_training_history(model_id,history)
  #to avoid concat of same history when re-executing this cell
  training_history = None
  plot_training_history(history)

# %% [markdown]
# Comme lors de notre précédent test, on constate de l'overfitting dès l'époque 3, même si les performances sur les données de validation continuent de progresser. On aurait pu s'arrêter à l'époque 6. Attendre nous a quand même permis de gagner quelques points sur la troisième décimale, mais on peut s'interroger si l'overfitting que le modèle a subi en vaut la chandelle.
#
# On remarque que seule 14 époques sont présentes. Cela signifie que la callback early_stopping a été appelée faute de progrès significatifs observés depuis l'époque 9 (le paramètre **patience** étant mis à 5). Cela a tout de même permis de limiter un peu l'overfitting.
#
# On note également qu'on atteint la **loss** la plus basse qu'on ait vue (1.1xxx). L'extraction de features avec **VGG16** apporte un vrai plus en un nombre d'époques assez faibles (6 époques suffisent pour presque atteindre le minimum sur les données de validation).

# %% [markdown]
# On va maintenant afficher le rapport de classification qui va nous donner une vision détaillée par classe des scores de prédiction.

# %%
print(classification_report(y_test.astype("str"),test_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#           10       0.35      0.46      0.39       311
#         1140       0.49      0.61      0.54       267
#         1160       0.86      0.88      0.87       396
#         1180       0.27      0.30      0.29        76
#         1280       0.45      0.29      0.35       487
#         1281       0.33      0.25      0.28       207
#         1300       0.63      0.62      0.63       505
#         1301       0.72      0.54      0.62        81
#         1302       0.45      0.49      0.47       249
#         1320       0.41      0.48      0.45       324
#         1560       0.68      0.44      0.53       507
#         1920       0.68      0.84      0.75       431
#         1940       0.51      0.70      0.59        81
#         2060       0.49      0.43      0.46       499
#         2220       0.36      0.33      0.34        82
#         2280       0.69      0.62      0.65       476
#         2403       0.67      0.44      0.53       477
#         2462       0.56      0.51      0.53       142
#         2522       0.69      0.59      0.63       499
#         2582       0.34      0.48      0.40       259
#         2583       0.87      0.67      0.76      1021
#         2585       0.32      0.53      0.39       250
#         2705       0.38      0.70      0.49       276
#         2905       0.40      0.82      0.53        87
#           40       0.47      0.39      0.43       251
#           50       0.37      0.51      0.43       168
#           60       0.52      0.65      0.58        83
#
#     accuracy                           0.55      8492
#    macro avg       0.52      0.54      0.52      8492
# weighted avg       0.58      0.55      0.56      8492

# %% [markdown]
# Par rapport à la modélisation précédente, on voit que les classes **1160**, **1920** et **2583** ont encore vu leur **f1-score** progresser.
#
# Le **f1-score** minimum est de **0.28**, ce qui reste raisonnable.

# %% [markdown]
# Affichons la matrice de confusion sous forme de heatmap pour plus de lisibilité.

# %%
cm = pd.crosstab(y_test.astype("str"),test_pred_class,rownames=["réel"],colnames=["prédit"])
plot_confusion_matrix(np.array(cm))

# %% [markdown]
# La diagonale des vrais positifs s'est encore renforcée. Les faux positifs les plus élevés restent à peu près les mêmes, si ce n'est une confusion plus élevée (qui s'explique aussi par l'augmentation du nombre de données) entre "mobilier extérieur" et "mobilier intérieur", confusion qui là encore, paraît logique.

# %% [markdown]
# ## Résumé

# %% [markdown]
# Nous avons atteint la fin de l'évaluation de cette modélisation. Affichons le rapport du modèle.

# %%
reporting_df.loc[model_id].T
# Out:
# model_name                                                            Modèle 3.2
# dataset_source                 output/data-preprocessing-resampling/df_{train...
# dataset_resampled                                                           True
# image_dataset_source             output/data-preprocessing-images/images_pre.zip
# image_dataset_zoomed                                                        True
# train_size                                                              109566.0
# image_size                                                                 224.0
# image_color_rgb                                                             True
# batch_size                                                                  64.0
# image_data_generator_params    {'preprocessing_function': 'preprocess_input',...
# start_lr                                                                   0.001
# last_lr                                                                    0.001
# optimizer                                                                   adam
# target_epochs                                                               20.0
# last_epoch                                                                  14.0
# fit_complete                                                                True
# f1_score                                                                0.665658
# val_f1_score                                                            0.561671
# test_f1_score                                                           0.556558
# accuracy                                                                0.669275
# val_accuracy                                                            0.552675
# test_accuracy                                                           0.552991
# loss                                                                    1.067026
# val_loss                                                                 1.61175
# remarks                                                                      NaN
# Name: 321, dtype: object

# %% [markdown]
# # Modélisation 3

# %% [markdown]
# On va maintenant tenter d'ajuster _au plus près_ les poids du modèle entrainé dans la section 2. Pour cela on va poursuivre son entraînement mais en dégelant les 4 dernières couches du modèle **VGG16**. On espère ainsi améliorer un peu la spécificité de l'extraction de features qui devrait être mieux adaptée à notre tâche de classification et obtenir un meilleur f1 score.

# %%
model_id = 331

# %% [markdown]
# ## Import des données

# %% [markdown]
# On réutilise les données importées dans la modélisation 1

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# On réutilise le preprocessing de la modélisation 2

# %% [markdown]
# ## Initialisation du rapport de modèle

# %% [markdown]
# Si un fichier **model_reporting.csv** existe, on le charge. Autrement, on en crée un nouveau.

# %%
Path(output_dir).mkdir(parents=True, exist_ok=True)
try:
  reporting_df = load_reporting_df()
  print("loaded ",output_dir+"/model_reporting.csv")
except FileNotFoundError:
  reporting_df = create_reporting_df()
  print(output_dir+"/model_reporting.csv","not found. creating one")
# Out:
# loaded  output/data-modeling-images-3/model_reporting.csv

# %%
reporting_df.head()
# Out:
#              model_name                                     dataset_source  \
# model_id
# 0         Example model            output/data-exploration/X_train_pre.csv
# 311          Modèle 3.1  output/data-preprocessing-resampling/df_{train...
# 321          Modèle 3.2  output/data-preprocessing-resampling/df_{train...
# 331          Modèle 3.3  output/data-preprocessing-resampling/df_{train...
# 341        Modèle 3.4.1  output/data-preprocessing-resampling/df_{train...
#
#           dataset_resampled                             image_dataset_source  \
# model_id
# 0                     False                                  data/images.zip
# 311                    True  output/data-preprocessing-images/images_pre.zip
# 321                    True  output/data-preprocessing-images/images_pre.zip
# 331                    True  output/data-preprocessing-images/images_pre.zip
# 341                    True  output/data-preprocessing-images/images_pre.zip
#
#           image_dataset_zoomed  train_size  image_size  image_color_rgb  \
# model_id
# 0                        False     42458.0       300.0             True
# 311                       True     21913.0       224.0             True
# 321                       True    109566.0       224.0             True
# 331                       True    109566.0       224.0             True
# 341                       True    109566.0       224.0             True
#
#           batch_size                        image_data_generator_params  ...  \
# model_id                                                                 ...
# 0               32.0  {'rescale': 0.00392156862745098, 'shear_range'...  ...
# 311             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 321             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 331             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 341             32.0  {'preprocessing_function': 'preprocess_input',...  ...
#
#           fit_complete  f1_score val_f1_score  test_f1_score  accuracy  \
# model_id
# 0                 True  0.420000     0.370000       0.350000  0.570000
# 311               True  0.552243     0.520430       0.514401  0.558103
# 321               True  0.665658     0.561671       0.556558  0.669275
# 331               True  0.739655     0.601403       0.601500  0.742927
# 341               True  0.415287     0.483479       0.492511  0.421559
#
#           val_accuracy  test_accuracy      loss  val_loss  \
# model_id
# 0             0.390000       0.410000  1.567000  2.657000
# 311           0.516927       0.515191  1.433475  1.707712
# 321           0.552675       0.552991  1.067026  1.611750
# 331           0.597656       0.598681  0.806426  1.479870
# 341           0.472641       0.480217  1.990221  1.791615
#
#                                                     remarks
# model_id
# 0         Ceci n'est pas un vrai modèle. C'est juste un ...
# 311                                                     NaN
# 321                                                     NaN
# 331       4 dernière couches de VGG16 repassées à traina...
# 341         early_stopping plus agressif + dropout_rate=0.5
#
# [5 rows x 25 columns]

# %% [markdown]
# Ajoutons une ligne correspondant à notre modèle et commençons à renseigner ses informations.

# %%
add_reporting_line(model_id,"Modèle 3.3")

# %% [markdown]
# On peut déjà renseigner les informations sur les données sources qu'on utilise.

# %%
update_reporting_line(model_id,{
    "dataset_source": "output/data-preprocessing-resampling/df_{train,val,test}.zip",
    "dataset_resampled": True,
    "image_dataset_source" : "output/data-preprocessing-images/images_pre.zip",
    "image_dataset_zoomed" : True,
    "train_size": len(X_train),
})

# %% [markdown]
# ## Générateurs d'images

# %% [markdown]
# Dans cette section, nous allons créer les générateurs qui vont fournir au modèle les images.

# %% [markdown]
# On réutilise les mêmes générateurs que lors de la modélisation 2

# %%
update_reporting_line(model_id, {
    "image_data_generator_params" : {
      "preprocessing_function":"preprocess_input",
      "rotation_range":20,
      "width_shift_range":0.2,
      "height_shift_range":0.2,
      "shear_range":5,
      "zoom_range":0.1,
      "horizontal_flip":True,
      "vertical_flip":False,
      "fill_mode":'nearest'
      }
})


update_reporting_line(model_id, {
    "batch_size":batch_size,
    "image_size": target_img_size[0],
    "image_color_rgb": True
})

train_generator = train_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_train['imagefile'],"prdtypecode": y_train.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras
)
# Out:
# Found 109566 validated image filenames belonging to 27 classes.

# %%
validation_generator = validation_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_validation['imagefile'],"prdtypecode": y_validation.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras
)
# Out:
# Found 8492 validated image filenames belonging to 27 classes.

# %%
test_generator = test_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_test['imagefile'],"prdtypecode": y_test.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras,
    shuffle=False
)
# Out:
# Found 8492 validated image filenames belonging to 27 classes.

# %% [markdown]
# ## Création du modèle

# %% [markdown]
# S'il n'y a pas encore de modèle enregistré, on récupère le modèle de la section 2 en veillant à repasser la propriété **trainable** des 4 dernieres couches de **VGG16** à **true**. On choisit d'utiliser un taux d'apprentissage divisé par 10 de 0.0001, pour tenter d'ajuster au plus près les poids.

# %%
model = load_saved_model(model_id)
start_lr = 0.0001
if model == None:
  print("re-load model 321")
  model = load_saved_model(321)
  vgg = model.layers[0]
  for layer in vgg.layers[-4:]:
    layer.trainable = True
  model.compile(
      optimizer=Adam(learning_rate=start_lr),
      loss='categorical_crossentropy',
      metrics=['accuracy',w_f1_score]
  )
  update_reporting_line(model_id,{
      "start_lr": start_lr,
      "optimizer": "adam",
      "remarks": "4 dernière couches de VGG16 repassées à trainable=True"
  })
else:
  print("re-loaded model "+str(model_id))

model.summary()
# Out:
# Load previous model from output/data-modeling-images-3/model-331.keras
# re-loaded model 331
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 27)                13851
#
# =================================================================
# Total params: 15778651 (60.19 MB)
# Trainable params: 8143387 (31.06 MB)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________

# %% [markdown]
# ## Entraînement du modèle

# %% [markdown]
# On procède à l'entraînement du modèle uniquement si le rapport nous indique que son entraînement n'est pas fini (colonne **fit_complete**).
#
# Dans le cas de la reprise d'un entraînement interrompu, on reprend l'entraînement pour le nombre d'époques qu'il reste à accomplir pour atteindre le nombre d'époques visé (**target_epochs**) qu'on passe cette fois à 10, un nombre qui dervait être suffisant pour ajuster le réseau de neurones sans pour autant provoquer trop d'overfitting.
#
# Une fois l'entraînement terminé, on passe **fit_complete** à **True**.
#
# Les métriques sur la progression de l'entraînement ainsi que les meilleurs modèles sont récoltées et enregistrées dans la callback **LogBest**.

# %%
target_epochs = 10
if not get_reporting_value(model_id,"fit_complete",False):
  update_reporting_line(model_id,{
      "target_epochs": target_epochs
  })
  training_history = model.fit(
      train_generator,
      validation_data=validation_generator,
      steps_per_epoch=train_generator.samples // batch_size,
      validation_steps = validation_generator.samples // batch_size,
      epochs=target_epochs - int(get_reporting_value(model_id,"last_epoch",0)),
      verbose=1,
      callbacks=[LogBest(model_id),early_stopping]
  )
  update_reporting_line(model_id,{"fit_complete":True})
else:
  print("No need to train model")
  training_history = None
# Out:
# No need to train model

# %% [markdown]
# ## Évaluation du modèle

# %% [markdown]
# Si un entraînement a eu lieu au cours de cette exécution du notebook, on recharge le meilleur modèle qu'on a trouvé.

# %%
if training_history != None:
  #if fit wad called, make sure to load best saved model, otherwise it's already loaded
  model = load_saved_model(model_id)

# %% [markdown]
# On teste le modèle sur l'ensemble de test.

# %%
test_pred = model.predict(test_generator,verbose=1)
# Out:
# 133/133 [==============================] - 52s 392ms/step

# %% [markdown]
# On doit convertir le résultat de **predict** depuis le format renvoyé par Keras, qui est une matrice de probabilités avec les classes en colonnes et les observations du jeu de test en lignes, en un tableau à 1 dimension contenant les classes prédites pour chaque observation.
#
# Pour cela, on extrait pour chaque observation l'index de la probabilité maximale de prédiction. On utilise ensuite cet index pour retrouver la classe correspondante dans **classes_keras**, la liste des classes telle qu'on la fournit à Keras.

# %%
test_pred_class = np.argmax(test_pred,axis=1)
test_pred_class = [classes_keras[c] for c in test_pred_class]

# %% [markdown]
# À partir des classes prédites et des observations réelles, on calcule le score F1 ainsi que l'accuracy de notre modèle, toujours sur le jeu de test.
#
# On enregistre ces informations dans le rapport.

# %%
f1_weighted = f1_score(y_test.astype("str"),test_pred_class,average="weighted")
accuracy = accuracy_score(y_test.astype("str"),test_pred_class)
update_reporting_line(model_id,{
    "test_f1_score":f1_weighted,
    "test_accuracy":accuracy
})

print("f1_score on test dataset=%.4f" % f1_weighted)
print("accuracy on test dataset=%.4f" % accuracy)
# Out:
# f1_score on test dataset=0.6015
# accuracy on test dataset=0.5987

# %% [markdown]
# On atteint un nouveau record pour les métriques de performances **accuracy** et **f1-score** qui sont maintenant de 0.60 toutes les deux.

# %% [markdown]
# Récupérons l'historique d'entraînement complet grâce à **get_full_training_history** qu'on va enregistrer. Puis, affichons deux graphiques :
#
# * L'évolution de l'**accuracy** et du **f1-score** en fonction des époques.
# * L'évolution des indicateurs de perte **loss** et **val_loss**.

# %%
history = get_full_training_history(model_id,training_history)
if history != None:
  save_training_history(model_id,history)
  #to avoid concat of same history when re-executing this cell
  training_history = None
  plot_training_history(history)

# %% [markdown]
# Bien que les courbes revèlent clairement une tendance à l'overfitting, on constate on constate une augmentation régulière bien que plus lente des performances sur l'ensemble de validation qui passent progressivement de 0.56 à 0.6 sur 10 époques.

# %% [markdown]
# On va maintenant afficher le rapport de classification qui va nous donner une vision détaillée par classe des scores de prédiction.

# %%
print(classification_report(y_test.astype("str"),test_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#           10       0.43      0.56      0.49       311
#         1140       0.60      0.59      0.59       267
#         1160       0.93      0.89      0.91       396
#         1180       0.46      0.32      0.37        76
#         1280       0.49      0.34      0.40       487
#         1281       0.27      0.41      0.33       207
#         1300       0.63      0.74      0.68       505
#         1301       0.69      0.57      0.62        81
#         1302       0.40      0.51      0.45       249
#         1320       0.48      0.45      0.46       324
#         1560       0.58      0.51      0.54       507
#         1920       0.65      0.87      0.74       431
#         1940       0.61      0.74      0.67        81
#         2060       0.45      0.49      0.47       499
#         2220       0.43      0.26      0.32        82
#         2280       0.75      0.70      0.73       476
#         2403       0.67      0.59      0.63       477
#         2462       0.72      0.51      0.60       142
#         2522       0.73      0.60      0.65       499
#         2582       0.39      0.42      0.40       259
#         2583       0.89      0.72      0.80      1021
#         2585       0.39      0.52      0.45       250
#         2705       0.61      0.64      0.63       276
#         2905       0.51      0.83      0.63        87
#           40       0.62      0.51      0.56       251
#           50       0.39      0.43      0.41       168
#           60       0.58      0.76      0.66        83
#
#     accuracy                           0.60      8492
#    macro avg       0.57      0.57      0.56      8492
# weighted avg       0.62      0.60      0.60      8492

# %% [markdown]
# Le nouveau minimum parmi les **f1-score** de classes est 0.33 contre 0.28 la fois précédente. La classe **1160** atteint maintenant un maximum de 0.91.
#
# Trois classes passent la barre des 0.70 tandis que beaucoup s'en rapprochent (**1300**,**2522**, **60**,...).
#
# Si l'on examine attentivement le rapport, on remarque que la plupart des classes ont un **f1-score** supérieur ou égal à 0.6.

# %% [markdown]
# Affichons la matrice de confusion sous forme de heatmap pour plus de lisibilité.

# %%
cm = pd.crosstab(y_test.astype("str"),test_pred_class,rownames=["réel"],colnames=["prédit"])
plot_confusion_matrix(np.array(cm))

# %% [markdown]
# On a le droit à un diagonale de vrais positifs bien déssinée. Le nombre de faux positifs élevés semble avoir diminué par rapport au modélisations précédentes.
#
# On remarque que la classe **1180** _jeu plateau_ a un nombre assez faible de vrais positifs mais elle est aussi minoritaire dans l'ensemble de test avec seulement 76 observations. D'ailleurs, on note que la colonne contient peu de faux positifs. En d'autre terme, quand cette classes est reconnue, elle est bien reconnue ce qui n'exclue pas que le modèle prédise parfois d'autres classes qu'elle à sa place. C'est plutôt ce dernier mode de confusion qui prime d'ailleurs. On peut également vérifier ça dans le rapport de classification. Le **précision** pour cette classes est de 0.46 tandis que le **rappel** est de seulement 0.32.
#
# Il est interessant d'observer qu'on le problème inverse pour la classe **1281** (le **f1-score** le plus bas du rapport de classification) qui a un **rappel** de 0.41 largement supérieur à la **précision** qui est de 0.27. On peut d'ailleurs aisémment le vérifier sur la matrice de confusion en comparant la colonne et la ligne correspondant à la classe: La colonne contient bien plus de valeurs en dehors de la diagonale.

# %% [markdown]
# ## Résumé

# %% [markdown]
# Nous avons atteint la fin de l'évaluation de cette modélisation. Affichons le rapport du modèle.

# %%
reporting_df.loc[model_id].T
# Out:
# model_name                                                            Modèle 3.3
# dataset_source                 output/data-preprocessing-resampling/df_{train...
# dataset_resampled                                                           True
# image_dataset_source             output/data-preprocessing-images/images_pre.zip
# image_dataset_zoomed                                                        True
# train_size                                                              109566.0
# image_size                                                                 224.0
# image_color_rgb                                                             True
# batch_size                                                                  64.0
# image_data_generator_params    {'preprocessing_function': 'preprocess_input',...
# start_lr                                                                  0.0001
# last_lr                                                                   0.0001
# optimizer                                                                   adam
# target_epochs                                                               10.0
# last_epoch                                                                  10.0
# fit_complete                                                                True
# f1_score                                                                0.739655
# val_f1_score                                                            0.601403
# test_f1_score                                                             0.6015
# accuracy                                                                0.742927
# val_accuracy                                                            0.597656
# test_accuracy                                                           0.598681
# loss                                                                    0.806426
# val_loss                                                                 1.47987
# remarks                        4 dernière couches de VGG16 repassées à traina...
# Name: 331, dtype: object

# %% [markdown]
# # Modélisation 4.1

# %% [markdown]
# On a pu determiner que le modèle le plus perfomant jusqu'à présent est le modèle 331, lui même étant basé sur le modèle 221 mais avec les 4 dernières couches de **VGG16** dégelées.
#
# C'est donc ce modèle qu'on va séléctionner pour tenter de résoudre le problème d'overfitting qu'on a pu observer lors de son évaluation. Le lecteur curieux pourra consulter à nouveau les courbes d'appentissages du modèle qui montrent bien l'overfitting.
#
# Afin de diminuer l'overfitting, nous allons ajuster les paramètres suivants:
# - Augmenter le taux de dropout de notre classificateur
# - Utiliser un early stopping plus agressif qui permette de mettre fin à l'entraînement plus rapidement en cas de stagnation de là métrique **val_f1_score**
# - Baisser **batch_size**
#
# Nous allons toutefois procéder en deux temps, dans cette section nous allons entrainer le modèle sans dégeler les 4 dernières couches.
#
# C'est seulement dans la section 5 qu'on finalisera le modèle en dégelant les couches

# %%
model_id = 341

# %% [markdown]
# ## Import des données

# %% [markdown]
# On réutilise les données importées dans la modélisation 1

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# On réutilise le preprocessing de la modélisation 2

# %% [markdown]
# ## Initialisation du rapport de modèle

# %% [markdown]
# Si un fichier **model_reporting.csv** existe, on le charge. Autrement, on en crée un nouveau.

# %%
Path(output_dir).mkdir(parents=True, exist_ok=True)
try:
  reporting_df = load_reporting_df()
  print("loaded ",output_dir+"/model_reporting.csv")
except FileNotFoundError:
  reporting_df = create_reporting_df()
  print(output_dir+"/model_reporting.csv","not found. creating one")
# Out:
# loaded  output/data-modeling-images-3/model_reporting.csv

# %%
reporting_df.head()
# Out:
#              model_name                                     dataset_source  \
# model_id
# 0         Example model            output/data-exploration/X_train_pre.csv
# 311          Modèle 3.1  output/data-preprocessing-resampling/df_{train...
# 321          Modèle 3.2  output/data-preprocessing-resampling/df_{train...
# 331          Modèle 3.3  output/data-preprocessing-resampling/df_{train...
# 341        Modèle 3.4.1  output/data-preprocessing-resampling/df_{train...
#
#           dataset_resampled                             image_dataset_source  \
# model_id
# 0                     False                                  data/images.zip
# 311                    True  output/data-preprocessing-images/images_pre.zip
# 321                    True  output/data-preprocessing-images/images_pre.zip
# 331                    True  output/data-preprocessing-images/images_pre.zip
# 341                    True  output/data-preprocessing-images/images_pre.zip
#
#           image_dataset_zoomed  train_size  image_size  image_color_rgb  \
# model_id
# 0                        False     42458.0       300.0             True
# 311                       True     21913.0       224.0             True
# 321                       True    109566.0       224.0             True
# 331                       True    109566.0       224.0             True
# 341                       True    109566.0       224.0             True
#
#           batch_size                        image_data_generator_params  ...  \
# model_id                                                                 ...
# 0               32.0  {'rescale': 0.00392156862745098, 'shear_range'...  ...
# 311             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 321             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 331             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 341             32.0  {'preprocessing_function': 'preprocess_input',...  ...
#
#           fit_complete  f1_score val_f1_score  test_f1_score  accuracy  \
# model_id
# 0                 True  0.420000     0.370000       0.350000  0.570000
# 311               True  0.552243     0.520430       0.514401  0.558103
# 321               True  0.665658     0.561671       0.556558  0.669275
# 331               True  0.739655     0.601403       0.601500  0.742927
# 341               True  0.415287     0.483479       0.492511  0.421559
#
#           val_accuracy  test_accuracy      loss  val_loss  \
# model_id
# 0             0.390000       0.410000  1.567000  2.657000
# 311           0.516927       0.515191  1.433475  1.707712
# 321           0.552675       0.552991  1.067026  1.611750
# 331           0.597656       0.598681  0.806426  1.479870
# 341           0.472641       0.480217  1.990221  1.791615
#
#                                                     remarks
# model_id
# 0         Ceci n'est pas un vrai modèle. C'est juste un ...
# 311                                                     NaN
# 321                                                     NaN
# 331       4 dernière couches de VGG16 repassées à traina...
# 341         early_stopping plus agressif + dropout_rate=0.5
#
# [5 rows x 25 columns]

# %% [markdown]
# Ajoutons une ligne correspondant à notre modèle et commençons à renseigner ses informations.

# %%
add_reporting_line(model_id,"Modèle 3.4.1")

# %% [markdown]
# On peut déjà renseigner les informations sur les données sources qu'on utilise.

# %%
update_reporting_line(model_id,{
    "dataset_source": "output/data-preprocessing-resampling/df_{train,val,test}.zip",
    "dataset_resampled": True,
    "image_dataset_source" : "output/data-preprocessing-images/images_pre.zip",
    "image_dataset_zoomed" : True,
    "train_size": len(X_train),
})

# %% [markdown]
# ## Générateurs d'images

# %% [markdown]
# Dans cette section, nous allons créer les générateurs qui vont fournir au modèle les images.

# %% [markdown]
# On réutilise les mêmes générateurs que lors de la modélisation 2 si ce n'est qu'on baisse **batch_size** de 64 à 32

# %%
update_reporting_line(model_id, {
    "image_data_generator_params" : {
      "preprocessing_function":"preprocess_input",
      "rotation_range":20,
      "width_shift_range":0.2,
      "height_shift_range":0.2,
      "shear_range":5,
      "zoom_range":0.1,
      "horizontal_flip":True,
      "vertical_flip":False,
      "fill_mode":'nearest'
      }
})

batch_size = 32
update_reporting_line(model_id, {
    "batch_size":batch_size,
    "image_size": target_img_size[0],
    "image_color_rgb": True
})

train_generator = train_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_train['imagefile'],"prdtypecode": y_train.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras
)
# Out:
# Found 109566 validated image filenames belonging to 27 classes.

# %%
validation_generator = validation_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_validation['imagefile'],"prdtypecode": y_validation.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras
)
# Out:
# Found 8492 validated image filenames belonging to 27 classes.

# %%
test_generator = test_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_test['imagefile'],"prdtypecode": y_test.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras,
    shuffle=False
)
# Out:
# Found 8492 validated image filenames belonging to 27 classes.

# %% [markdown]
# ## Création du modèle

# %% [markdown]
# S'il n'y a pas encore de modèle enregistré, on en crée un en veillant à utiliser un taux de dropout de 0.5 au lieu de 0.2. On repasse aussi **start_lr_** à 0.001 pour cette première phase d'entraînement.

# %%
model = load_saved_model(model_id)
start_lr = 0.001
if model == None:
  model = build_model(target_img_size,dropout_rate=0.5)
  model.compile(
      optimizer=Adam(learning_rate=start_lr),
      loss='categorical_crossentropy',
      metrics=['accuracy',w_f1_score]
  )
  update_reporting_line(model_id,{
      "start_lr": start_lr,
      "optimizer": "adam",
      "remarks": "early_stopping plus agressif + dropout_rate=0.5"
  })

model.summary()
# Out:
# Load previous model from output/data-modeling-images-3/model-341.keras
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 27)                13851
#
# =================================================================
# Total params: 15778651 (60.19 MB)
# Trainable params: 1063963 (4.06 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %% [markdown]
# ## Entraînement du modèle

# %% [markdown]
# On recrée une callback **EarlyStopping** plus agressive en diminuant le paramètre **patience** de 5 à 3.

# %%
earlier_stopping = EarlyStopping(
              monitor='val_w_f1_score',
              mode="max", #stop when f1 score is not increasing anymore
              patience=3,           # Number of epochs with no improvement
              min_delta=1e-2,       # Minimum change to qualify as an improvement
)

# %% [markdown]
# On procède à l'entraînement du modèle uniquement si le rapport nous indique que son entraînement n'est pas fini (colonne **fit_complete**).
#
# Dans le cas de la reprise d'un entraînement interrompu, on reprend l'entraînement pour le nombre d'époques qu'il reste à accomplir pour atteindre le nombre d'époques visé (**target_epochs**) qu'on repasse à 20.
#
# Une fois l'entraînement terminé, on passe **fit_complete** à **True**.
#
# Les métriques sur la progression de l'entraînement ainsi que les meilleurs modèles sont récoltées et enregistrées dans la callback **LogBest**.
#
# On veille à passer la nouvelle callback **earlier_stopping** pour se prémunir contre une prolongation de l'entrainement qui amènerait trop d'overfitting.

# %%
target_epochs = 20
if not get_reporting_value(model_id,"fit_complete",False):
  update_reporting_line(model_id,{
      "target_epochs": target_epochs
  })
  training_history = model.fit(
      train_generator,
      validation_data=validation_generator,
      steps_per_epoch=train_generator.samples // batch_size,
      validation_steps = validation_generator.samples // batch_size,
      epochs=target_epochs - int(get_reporting_value(model_id,"last_epoch",0)),
      verbose=1,
      callbacks=[earlier_stopping,LogBest(model_id)]
  )
  update_reporting_line(model_id,{"fit_complete":True})
else:
  print("No need to train model")
  training_history = None
# Out:
# No need to train model

# %% [markdown]
# ## Évaluation du modèle

# %% [markdown]
# Si un entraînement a eu lieu au cours de cette exécution du notebook, on recharge le meilleur modèle qu'on a trouvé.

# %%
if training_history != None:
  #if fit wad called, make sure to load best saved model, otherwise it's already loaded
  model = load_saved_model(model_id)

# %% [markdown]
# On teste le modèle sur l'ensemble de test.

# %%
test_pred = model.predict(test_generator,verbose=1)
# Out:
# 266/266 [==============================] - 55s 181ms/step

# %% [markdown]
# On doit convertir le résultat de **predict** depuis le format renvoyé par Keras, qui est une matrice de probabilités avec les classes en colonnes et les observations du jeu de test en lignes, en un tableau à 1 dimension contenant les classes prédites pour chaque observation.
#
# Pour cela, on extrait pour chaque observation l'index de la probabilité maximale de prédiction. On utilise ensuite cet index pour retrouver la classe correspondante dans **classes_keras**, la liste des classes telle qu'on la fournit à Keras.

# %%
test_pred_class = np.argmax(test_pred,axis=1)
test_pred_class = [classes_keras[c] for c in test_pred_class]

# %% [markdown]
# À partir des classes prédites et des observations réelles, on calcule le **f1-score** ainsi que l'**accuracy** de notre modèle, toujours sur le jeu de test.
#
# On enregistre ces informations dans le rapport.

# %%
f1_weighted = f1_score(y_test.astype("str"),test_pred_class,average="weighted")
accuracy = accuracy_score(y_test.astype("str"),test_pred_class)
update_reporting_line(model_id,{
    "test_f1_score":f1_weighted,
    "test_accuracy":accuracy
})

print("f1_score on test dataset=%.4f" % f1_weighted)
print("accuracy on test dataset=%.4f" % accuracy)
# Out:
# f1_score on test dataset=0.4925
# accuracy on test dataset=0.4802

# %% [markdown]
# On constate que les deux métriques ont baissé significativement par rapport au 0.56/0.55 de la modélisation 2

# %% [markdown]
# Récupérons l'historique d'entraînement complet grâce à **get_full_training_history** qu'on va enregistrer. Puis, affichons deux graphiques :
#
# * L'évolution de l'accuracy et du score F1 en fonction des époques.
# * L'évolution des indicateurs de perte **loss** et **val_loss**.

# %%
history = get_full_training_history(model_id,training_history)
if history != None:
  save_training_history(model_id,history)
  #to avoid concat of same history when re-executing this cell
  training_history = None
  plot_training_history(history)

# %% [markdown]
# Cette fois-ci, on ne decele aucun overfitting, bien au contraire. L'écart entre les courbes d'entrainement et de validation nous laisse penser qu'on dispose encore d'une bonne marge de manoeuvre pour améliorer les performances du modèle sans risquer d'overfitting.

# %% [markdown]
# On va maintenant afficher le rapport de classification qui va nous donner une vision détaillée par classe des scores de prédiction.

# %%
print(classification_report(y_test.astype("str"),test_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#           10       0.36      0.37      0.36       311
#         1140       0.44      0.55      0.49       267
#         1160       0.93      0.76      0.84       396
#         1180       0.28      0.26      0.27        76
#         1280       0.47      0.27      0.34       487
#         1281       0.33      0.08      0.13       207
#         1300       0.57      0.56      0.56       505
#         1301       0.33      0.59      0.42        81
#         1302       0.26      0.37      0.31       249
#         1320       0.37      0.37      0.37       324
#         1560       0.57      0.48      0.52       507
#         1920       0.81      0.73      0.77       431
#         1940       0.32      0.74      0.45        81
#         2060       0.50      0.29      0.37       499
#         2220       0.39      0.30      0.34        82
#         2280       0.71      0.46      0.56       476
#         2403       0.58      0.51      0.54       477
#         2462       0.54      0.37      0.44       142
#         2522       0.66      0.51      0.57       499
#         2582       0.42      0.27      0.32       259
#         2583       0.84      0.56      0.67      1021
#         2585       0.15      0.45      0.23       250
#         2705       0.31      0.82      0.45       276
#         2905       0.22      0.77      0.34        87
#           40       0.45      0.33      0.38       251
#           50       0.26      0.38      0.31       168
#           60       0.35      0.71      0.47        83
#
#     accuracy                           0.48      8492
#    macro avg       0.46      0.48      0.44      8492
# weighted avg       0.55      0.48      0.49      8492

# %% [markdown]
# Nous ne détaillerons pas le rapport de classification cette fois, préférant axer nos efforts sur regagner de la performance sans overfitting dans les prochaines modélisations.

# %% [markdown]
# Affichons la matrice de confusion sous forme de heatmap pour plus de lisibilité.

# %%
cm = pd.crosstab(y_test.astype("str"),test_pred_class,rownames=["réel"],colnames=["prédit"])
plot_confusion_matrix(np.array(cm))

# %% [markdown]
# Nous ne détaillerons pas la matrice de confusion cette fois, préférant axer nos efforts sur regagner de la performance sans overfitting dans les prochaines modélisations.

# %% [markdown]
# ## Résumé

# %% [markdown]
# Nous avons atteint la fin de l'évaluation de cette modélisation. Affichons le rapport du modèle.

# %%
reporting_df.loc[model_id].T
# Out:
# model_name                                                          Modèle 3.4.1
# dataset_source                 output/data-preprocessing-resampling/df_{train...
# dataset_resampled                                                           True
# image_dataset_source             output/data-preprocessing-images/images_pre.zip
# image_dataset_zoomed                                                        True
# train_size                                                              109566.0
# image_size                                                                 224.0
# image_color_rgb                                                             True
# batch_size                                                                  32.0
# image_data_generator_params    {'preprocessing_function': 'preprocess_input',...
# start_lr                                                                   0.001
# last_lr                                                                    0.001
# optimizer                                                                   adam
# target_epochs                                                               20.0
# last_epoch                                                                   6.0
# fit_complete                                                                True
# f1_score                                                                0.415287
# val_f1_score                                                            0.483479
# test_f1_score                                                           0.492511
# accuracy                                                                0.421559
# val_accuracy                                                            0.472641
# test_accuracy                                                           0.480217
# loss                                                                    1.990221
# val_loss                                                                1.791615
# remarks                          early_stopping plus agressif + dropout_rate=0.5
# Name: 341, dtype: object

# %% [markdown]
# # Modélisation 4.2

# %% [markdown]
# La modélisation 4.1 nous a révélé qu'on a peut-être été un peu radical dans l'augmentation du taux de dropout. Nous l'avions passé de 0.2 à 0.5.
#
# Le problème d'overfitting a certes été réglé, mais en revanche, l'apprentissage du modèle s'est ralenti pour atteindre le f1-score modeste de 0.49 au bout de 4 époques pour ensuite stagner et finalement être interrompu par notre callback **early_stopping** à la 6ième époque.
#
# Cette fois-ci, nous allons être plus mesuré et couper la poire en deux en passant le dropout à 0.35 pour tenter de trouver un bon équilibre entre overfitting et vitesse d'apprentissage.

# %%
model_id = 342

# %% [markdown]
# ## Import des données

# %% [markdown]
# On réutilise les données importées dans la modélisation 1

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# On réutilise le preprocessing de la modélisation 2

# %% [markdown]
# ## Initialisation du rapport de modèle

# %% [markdown]
# Si un fichier **model_reporting.csv** existe, on le charge. Autrement, on en crée un nouveau.

# %%
Path(output_dir).mkdir(parents=True, exist_ok=True)
try:
  reporting_df = load_reporting_df()
  print("loaded ",output_dir+"/model_reporting.csv")
except FileNotFoundError:
  reporting_df = create_reporting_df()
  print(output_dir+"/model_reporting.csv","not found. creating one")
# Out:
# loaded  output/data-modeling-images-3/model_reporting.csv

# %%
reporting_df.head()
# Out:
#              model_name                                     dataset_source  \
# model_id
# 0         Example model            output/data-exploration/X_train_pre.csv
# 311          Modèle 3.1  output/data-preprocessing-resampling/df_{train...
# 321          Modèle 3.2  output/data-preprocessing-resampling/df_{train...
# 331          Modèle 3.3  output/data-preprocessing-resampling/df_{train...
# 341        Modèle 3.4.1  output/data-preprocessing-resampling/df_{train...
#
#           dataset_resampled                             image_dataset_source  \
# model_id
# 0                     False                                  data/images.zip
# 311                    True  output/data-preprocessing-images/images_pre.zip
# 321                    True  output/data-preprocessing-images/images_pre.zip
# 331                    True  output/data-preprocessing-images/images_pre.zip
# 341                    True  output/data-preprocessing-images/images_pre.zip
#
#           image_dataset_zoomed  train_size  image_size  image_color_rgb  \
# model_id
# 0                        False     42458.0       300.0             True
# 311                       True     21913.0       224.0             True
# 321                       True    109566.0       224.0             True
# 331                       True    109566.0       224.0             True
# 341                       True    109566.0       224.0             True
#
#           batch_size                        image_data_generator_params  ...  \
# model_id                                                                 ...
# 0               32.0  {'rescale': 0.00392156862745098, 'shear_range'...  ...
# 311             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 321             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 331             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 341             32.0  {'preprocessing_function': 'preprocess_input',...  ...
#
#           fit_complete  f1_score val_f1_score  test_f1_score  accuracy  \
# model_id
# 0                 True  0.420000     0.370000       0.350000  0.570000
# 311               True  0.552243     0.520430       0.514401  0.558103
# 321               True  0.665658     0.561671       0.556558  0.669275
# 331               True  0.739655     0.601403       0.601500  0.742927
# 341               True  0.415287     0.483479       0.492511  0.421559
#
#           val_accuracy  test_accuracy      loss  val_loss  \
# model_id
# 0             0.390000       0.410000  1.567000  2.657000
# 311           0.516927       0.515191  1.433475  1.707712
# 321           0.552675       0.552991  1.067026  1.611750
# 331           0.597656       0.598681  0.806426  1.479870
# 341           0.472641       0.480217  1.990221  1.791615
#
#                                                     remarks
# model_id
# 0         Ceci n'est pas un vrai modèle. C'est juste un ...
# 311                                                     NaN
# 321                                                     NaN
# 331       4 dernière couches de VGG16 repassées à traina...
# 341         early_stopping plus agressif + dropout_rate=0.5
#
# [5 rows x 25 columns]

# %% [markdown]
# Ajoutons une ligne correspondant à notre modèle et commençons à renseigner ses informations.

# %%
add_reporting_line(model_id,"Modèle 3.4.2")

# %% [markdown]
# On peut déjà renseigner les informations sur les données sources qu'on utilise.

# %%
update_reporting_line(model_id,{
    "dataset_source": "output/data-preprocessing-resampling/df_{train,val,test}.zip",
    "dataset_resampled": True,
    "image_dataset_source" : "output/data-preprocessing-images/images_pre.zip",
    "image_dataset_zoomed" : True,
    "train_size": len(X_train),
})

# %% [markdown]
# ## Générateurs d'images

# %% [markdown]
# Dans cette section, nous allons créer les générateurs qui vont fournir au modèle les images.

# %% [markdown]
# On réutilise les mêmes générateurs que lors de la modélisation 2 si ce n'est qu'on va baisser **batch_size** de 64 à 32

# %%
update_reporting_line(model_id, {
    "image_data_generator_params" : {
      "preprocessing_function":"preprocess_input",
      "rotation_range":20,
      "width_shift_range":0.2,
      "height_shift_range":0.2,
      "shear_range":5,
      "zoom_range":0.1,
      "horizontal_flip":True,
      "vertical_flip":False,
      "fill_mode":'nearest'
      }
})

batch_size = 32
update_reporting_line(model_id, {
    "batch_size":batch_size,
    "image_size": target_img_size[0],
    "image_color_rgb": True
})

train_generator = train_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_train['imagefile'],"prdtypecode": y_train.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras
)
# Out:
# Found 109566 validated image filenames belonging to 27 classes.

# %%
validation_generator = validation_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_validation['imagefile'],"prdtypecode": y_validation.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras
)
# Out:
# Found 8492 validated image filenames belonging to 27 classes.

# %%
test_generator = test_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_test['imagefile'],"prdtypecode": y_test.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras,
    shuffle=False
)
# Out:
# Found 8492 validated image filenames belonging to 27 classes.

# %% [markdown]
# ## Création du modèle

# %% [markdown]
# S'il n'y a pas encore de modèle enregistré, on en crée un en veillant à utiliser un taux de dropout de 0.35 au lieu de 0.5. On repasse aussi **start_lr_** à 0.001.

# %%
model = load_saved_model(model_id)
start_lr = 0.001
if model == None:
  model = build_model(target_img_size,dropout_rate=0.35)
  model.compile(
      optimizer=Adam(learning_rate=start_lr),
      loss='categorical_crossentropy',
      metrics=['accuracy',w_f1_score]
  )
  update_reporting_line(model_id,{
      "start_lr": start_lr,
      "optimizer": "adam",
      "remarks": "early_stopping plus agressif + dropout_rate=0.35"
  })

model.summary()
# Out:
# Load previous model from output/data-modeling-images-3/model-342.keras
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 27)                13851
#
# =================================================================
# Total params: 15778651 (60.19 MB)
# Trainable params: 1063963 (4.06 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %% [markdown]
# ## Entraînement du modèle

# %% [markdown]
# On procède à l'entraînement du modèle uniquement si le rapport nous indique que son entraînement n'est pas fini (colonne **fit_complete**).
#
# Dans le cas de la reprise d'un entraînement interrompu, on reprend l'entraînement pour le nombre d'époques qu'il reste à accomplir pour atteindre le nombre d'époques visé (**target_epochs**) qu'on repasse à 20.
#
# Une fois l'entraînement terminé, on passe **fit_complete** à **True**.
#
# Les métriques sur la progression de l'entraînement ainsi que les meilleurs modèles sont récoltées et enregistrées dans la callback **LogBest**.
#
# On veille à passer la nouvelle callback **earlier_stopping** pour se prémunir contre une prolongation de l'entraînement qui amènerait trop d'overfitting.

# %%
target_epochs = 20
if not get_reporting_value(model_id,"fit_complete",False):
  update_reporting_line(model_id,{
      "target_epochs": target_epochs
  })
  training_history = model.fit(
      train_generator,
      validation_data=validation_generator,
      steps_per_epoch=train_generator.samples // batch_size,
      validation_steps = validation_generator.samples // batch_size,
      epochs=target_epochs - int(get_reporting_value(model_id,"last_epoch",0)),
      verbose=1,
      callbacks=[earlier_stopping,LogBest(model_id)]
  )
  update_reporting_line(model_id,{"fit_complete":True})
else:
  print("No need to train model")
  training_history = None
# Out:
# No need to train model

# %% [markdown]
# ## Évaluation du modèle

# %% [markdown]
# Si un entraînement a eu lieu au cours de cette exécution du notebook, on recharge le meilleur modèle qu'on a trouvé.

# %%
if training_history != None:
  #if fit wad called, make sure to load best saved model, otherwise it's already loaded
  model = load_saved_model(model_id)

# %% [markdown]
# On teste le modèle sur l'ensemble de test.

# %%
test_pred = model.predict(test_generator,verbose=1)
# Out:
# 266/266 [==============================] - 47s 176ms/step

# %% [markdown]
# On doit convertir le résultat de **predict** depuis le format renvoyé par Keras, qui est une matrice de probabilités avec les classes en colonnes et les observations du jeu de test en lignes, en un tableau à 1 dimension contenant les classes prédites pour chaque observation.
#
# Pour cela, on extrait pour chaque observation l'index de la probabilité maximale de prédiction. On utilise ensuite cet index pour retrouver la classe correspondante dans **classes_keras**, la liste des classes telle qu'on la fournit à Keras.

# %%
test_pred_class = np.argmax(test_pred,axis=1)
test_pred_class = [classes_keras[c] for c in test_pred_class]

# %% [markdown]
# À partir des classes prédites et des observations réelles, on calcule le score F1 ainsi que l'accuracy de notre modèle, toujours sur le jeu de test.
#
# On enregistre ces informations dans le rapport.

# %%
f1_weighted = f1_score(y_test.astype("str"),test_pred_class,average="weighted")
accuracy = accuracy_score(y_test.astype("str"),test_pred_class)
update_reporting_line(model_id,{
    "test_f1_score":f1_weighted,
    "test_accuracy":accuracy
})

print("f1_score on test dataset=%.4f" % f1_weighted)
print("accuracy on test dataset=%.4f" % accuracy)
# Out:
# f1_score on test dataset=0.5128
# accuracy on test dataset=0.5061

# %% [markdown]
# On observe une progression de 0.02 des métriques par rapport à la modélisation précédente

# %% [markdown]
# Récupérons l'historique d'entraînement complet grâce à **get_full_training_history** qu'on va enregistrer. Puis, affichons deux graphiques :
#
# * L'évolution de l'accuracy et du score F1 en fonction des époques.
# * L'évolution des indicateurs de perte **loss** et **val_loss**.

# %%
history = get_full_training_history(model_id,training_history)
if history != None:
  save_training_history(model_id,history)
  #to avoid concat of same history when re-executing this cell
  training_history = None
  plot_training_history(history)

# %% [markdown]
# La position relative des courbes de validation et d'entraînement montre qu'on n'a toujours pas d'overfitting jusqu'à l'époque 7 où elles se croisent.

# %% [markdown]
# On va maintenant afficher le rapport de classification qui va nous donner une vision détaillée par classe des scores de prédiction.

# %%
print(classification_report(y_test.astype("str"),test_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#           10       0.36      0.29      0.32       311
#         1140       0.48      0.57      0.52       267
#         1160       0.92      0.79      0.85       396
#         1180       0.28      0.22      0.25        76
#         1280       0.48      0.25      0.33       487
#         1281       0.27      0.18      0.21       207
#         1300       0.51      0.66      0.58       505
#         1301       0.39      0.57      0.46        81
#         1302       0.27      0.45      0.34       249
#         1320       0.39      0.42      0.41       324
#         1560       0.54      0.47      0.50       507
#         1920       0.80      0.78      0.79       431
#         1940       0.34      0.79      0.48        81
#         2060       0.54      0.36      0.43       499
#         2220       0.23      0.40      0.29        82
#         2280       0.67      0.55      0.60       476
#         2403       0.60      0.53      0.56       477
#         2462       0.48      0.42      0.44       142
#         2522       0.72      0.48      0.58       499
#         2582       0.36      0.44      0.39       259
#         2583       0.86      0.56      0.68      1021
#         2585       0.29      0.31      0.30       250
#         2705       0.36      0.74      0.49       276
#         2905       0.26      0.78      0.39        87
#           40       0.35      0.44      0.39       251
#           50       0.26      0.41      0.32       168
#           60       0.46      0.75      0.57        83
#
#     accuracy                           0.51      8492
#    macro avg       0.46      0.50      0.46      8492
# weighted avg       0.55      0.51      0.51      8492

# %% [markdown]
# Nous ne détaillerons pas le rapport de classification cette fois préférant axer nos efforts sur regagner de la performance sans overfitting dans les prochaines modélisations.

# %% [markdown]
# Affichons la matrice de confusion sous forme de heatmap pour plus de lisibilité.

# %%
cm = pd.crosstab(y_test.astype("str"),test_pred_class,rownames=["réel"],colnames=["prédit"])
plot_confusion_matrix(np.array(cm))

# %% [markdown]
# Nous ne détaillerons pas la matrice de confusion cette fois, préférant axer nos efforts sur regagner de la performance sans overfitting dans les prochaines modélisations.

# %% [markdown]
# ## Résumé

# %% [markdown]
# Nous avons atteint la fin de l'évaluation de cette modélisation. Affichons le rapport du modèle.

# %%
reporting_df.loc[model_id].T
# Out:
# model_name                                                          Modèle 3.4.2
# dataset_source                 output/data-preprocessing-resampling/df_{train...
# dataset_resampled                                                           True
# image_dataset_source             output/data-preprocessing-images/images_pre.zip
# image_dataset_zoomed                                                        True
# train_size                                                              109566.0
# image_size                                                                 224.0
# image_color_rgb                                                             True
# batch_size                                                                  32.0
# image_data_generator_params    {'preprocessing_function': 'preprocess_input',...
# start_lr                                                                   0.001
# last_lr                                                                    0.001
# optimizer                                                                   adam
# target_epochs                                                               20.0
# last_epoch                                                                   7.0
# fit_complete                                                                True
# f1_score                                                                0.481566
# val_f1_score                                                             0.51619
# test_f1_score                                                           0.512809
# accuracy                                                                0.486169
# val_accuracy                                                             0.50625
# test_accuracy                                                           0.506123
# loss                                                                    1.739799
# val_loss                                                                1.648645
# remarks                         early_stopping plus agressif + dropout_rate=0.35
# Name: 342, dtype: object

# %% [markdown]
# # Modélisation 4.3

# %% [markdown]
# En ré-baissant le taux de dropout qu'on avait préalablement augmenté, on a pu regagner quelques points de **f1-score** entre les modélisations 4.1 et 4.2. Voyons si on peut encore en gagner quelques-uns en le passant de 0.35 à 0.3.

# %%
model_id = 343

# %% [markdown]
# ## Import des données

# %% [markdown]
# On réutilise les données importées dans la modélisation 1

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# On réutilise le preprocessing de la modélisation 2

# %% [markdown]
# ## Initialisation du rapport de modèle

# %% [markdown]
# Si un fichier **model_reporting.csv** existe, on le charge. Autrement, on en crée un nouveau.

# %%
Path(output_dir).mkdir(parents=True, exist_ok=True)
try:
  reporting_df = load_reporting_df()
  print("loaded ",output_dir+"/model_reporting.csv")
except FileNotFoundError:
  reporting_df = create_reporting_df()
  print(output_dir+"/model_reporting.csv","not found. creating one")
# Out:
# loaded  output/data-modeling-images-3/model_reporting.csv

# %%
reporting_df.head()
# Out:
#              model_name                                     dataset_source  \
# model_id
# 0         Example model            output/data-exploration/X_train_pre.csv
# 311          Modèle 3.1  output/data-preprocessing-resampling/df_{train...
# 321          Modèle 3.2  output/data-preprocessing-resampling/df_{train...
# 331          Modèle 3.3  output/data-preprocessing-resampling/df_{train...
# 341        Modèle 3.4.1  output/data-preprocessing-resampling/df_{train...
#
#           dataset_resampled                             image_dataset_source  \
# model_id
# 0                     False                                  data/images.zip
# 311                    True  output/data-preprocessing-images/images_pre.zip
# 321                    True  output/data-preprocessing-images/images_pre.zip
# 331                    True  output/data-preprocessing-images/images_pre.zip
# 341                    True  output/data-preprocessing-images/images_pre.zip
#
#           image_dataset_zoomed  train_size  image_size  image_color_rgb  \
# model_id
# 0                        False     42458.0       300.0             True
# 311                       True     21913.0       224.0             True
# 321                       True    109566.0       224.0             True
# 331                       True    109566.0       224.0             True
# 341                       True    109566.0       224.0             True
#
#           batch_size                        image_data_generator_params  ...  \
# model_id                                                                 ...
# 0               32.0  {'rescale': 0.00392156862745098, 'shear_range'...  ...
# 311             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 321             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 331             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 341             32.0  {'preprocessing_function': 'preprocess_input',...  ...
#
#           fit_complete  f1_score val_f1_score  test_f1_score  accuracy  \
# model_id
# 0                 True  0.420000     0.370000       0.350000  0.570000
# 311               True  0.552243     0.520430       0.514401  0.558103
# 321               True  0.665658     0.561671       0.556558  0.669275
# 331               True  0.739655     0.601403       0.601500  0.742927
# 341               True  0.415287     0.483479       0.492511  0.421559
#
#           val_accuracy  test_accuracy      loss  val_loss  \
# model_id
# 0             0.390000       0.410000  1.567000  2.657000
# 311           0.516927       0.515191  1.433475  1.707712
# 321           0.552675       0.552991  1.067026  1.611750
# 331           0.597656       0.598681  0.806426  1.479870
# 341           0.472641       0.480217  1.990221  1.791615
#
#                                                     remarks
# model_id
# 0         Ceci n'est pas un vrai modèle. C'est juste un ...
# 311                                                     NaN
# 321                                                     NaN
# 331       4 dernière couches de VGG16 repassées à traina...
# 341         early_stopping plus agressif + dropout_rate=0.5
#
# [5 rows x 25 columns]

# %% [markdown]
# Ajoutons une ligne correspondant à notre modèle et commençons à renseigner ses informations.

# %%
add_reporting_line(model_id,"Modèle 3.4.3")

# %% [markdown]
# On peut déjà renseigner les informations sur les données sources qu'on utilise.

# %%
update_reporting_line(model_id,{
    "dataset_source": "output/data-preprocessing-resampling/df_{train,val,test}.zip",
    "dataset_resampled": True,
    "image_dataset_source" : "output/data-preprocessing-images/images_pre.zip",
    "image_dataset_zoomed" : True,
    "train_size": len(X_train),
})

# %% [markdown]
# ## Générateurs d'images

# %% [markdown]
# Dans cette section, nous allons créer les générateurs qui vont fournir au modèle les images.

# %% [markdown]
# On réutilise les mêmes générateurs que lors de la modélisation 2 si ce n'est qu'on va baisser **batch_size** de 64 à 32

# %%
update_reporting_line(model_id, {
    "image_data_generator_params" : {
      "preprocessing_function":"preprocess_input",
      "rotation_range":20,
      "width_shift_range":0.2,
      "height_shift_range":0.2,
      "shear_range":5,
      "zoom_range":0.1,
      "horizontal_flip":True,
      "vertical_flip":False,
      "fill_mode":'nearest'
      }
})

batch_size = 32
update_reporting_line(model_id, {
    "batch_size":batch_size,
    "image_size": target_img_size[0],
    "image_color_rgb": True
})

train_generator = train_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_train['imagefile'],"prdtypecode": y_train.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras
)
# Out:
# Found 109566 validated image filenames belonging to 27 classes.

# %%
validation_generator = validation_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_validation['imagefile'],"prdtypecode": y_validation.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras
)
# Out:
# Found 8492 validated image filenames belonging to 27 classes.

# %%
test_generator = test_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_test['imagefile'],"prdtypecode": y_test.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras,
    shuffle=False
)
# Out:
# Found 8492 validated image filenames belonging to 27 classes.

# %% [markdown]
# ## Création du modèle

# %% [markdown]
# S'il n'y a pas encore de modèle enregistré, on en crée un en veillant à utiliser un taux de dropout de 0.30 au lieu de 0.35. On repasse aussi **start_lr_** à 0.001.

# %%
model = load_saved_model(model_id)
start_lr = 0.001
if model == None:
  model = build_model(target_img_size,dropout_rate=0.30)
  model.compile(
      optimizer=Adam(learning_rate=start_lr),
      loss='categorical_crossentropy',
      metrics=['accuracy',w_f1_score]
  )
  update_reporting_line(model_id,{
      "start_lr": start_lr,
      "optimizer": "adam",
      "remarks": "early_stopping plus agressif + dropout_rate=0.30"
  })

model.summary()
# Out:
# Load previous model from output/data-modeling-images-3/model-343.keras
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 27)                13851
#
# =================================================================
# Total params: 15778651 (60.19 MB)
# Trainable params: 1063963 (4.06 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %% [markdown]
# ## Entraînement du modèle

# %% [markdown]
# On procède à l'entraînement du modèle uniquement si le rapport nous indique que son entraînement n'est pas fini (colonne **fit_complete**).
#
# Dans le cas de la reprise d'un entraînement interrompu, on reprend l'entraînement pour le nombre d'époques qu'il reste à accomplir pour atteindre le nombre d'époques visé (**target_epochs**) qu'on repasse à 20.
#
# Une fois l'entraînement terminé, on passe **fit_complete** à **True**.
#
# Les métriques sur la progression de l'entraînement ainsi que les meilleurs modèles sont récoltées et enregistrées dans la callback **LogBest**.
#
# On veille à passer la nouvelle callback **earlier_stopping** pour se prémunir contre une prolongation de l'entrainement qui amènerait trop d'overfitting.

# %%
target_epochs = 20
if not get_reporting_value(model_id,"fit_complete",False):
  update_reporting_line(model_id,{
      "target_epochs": target_epochs
  })
  training_history = model.fit(
      train_generator,
      validation_data=validation_generator,
      steps_per_epoch=train_generator.samples // batch_size,
      validation_steps = validation_generator.samples // batch_size,
      epochs=target_epochs - int(get_reporting_value(model_id,"last_epoch",0)),
      verbose=1,
      callbacks=[earlier_stopping,LogBest(model_id)]
  )
  update_reporting_line(model_id,{"fit_complete":True})
else:
  print("No need to train model")
  training_history = None
# Out:
# No need to train model

# %% [markdown]
# ## Évaluation du modèle

# %% [markdown]
# Si un entraînement a eu lieu au cours de cette exécution du notebook, on recharge le meilleur modèle qu'on a trouvé.

# %%
if training_history != None:
  #if fit wad called, make sure to load best saved model, otherwise it's already loaded
  model = load_saved_model(model_id)

# %% [markdown]
# On teste le modèle sur l'ensemble de test.

# %%
test_pred = model.predict(test_generator,verbose=1)
# Out:
# 266/266 [==============================] - 46s 173ms/step

# %% [markdown]
# On doit convertir le résultat de **predict** depuis le format renvoyé par Keras, qui est une matrice de probabilités avec les classes en colonnes et les observations du jeu de test en lignes, en un tableau à 1 dimension contenant les classes prédites pour chaque observation.
#
# Pour cela, on extrait pour chaque observation l'index de la probabilité maximale de prédiction. On utilise ensuite cet index pour retrouver la classe correspondante dans **classes_keras**, la liste des classes telle qu'on la fournit à Keras.

# %%
test_pred_class = np.argmax(test_pred,axis=1)
test_pred_class = [classes_keras[c] for c in test_pred_class]

# %% [markdown]
# À partir des classes prédites et des observations réelles, on calcule le score F1 ainsi que l'accuracy de notre modèle, toujours sur le jeu de test.
#
# On enregistre ces informations dans le rapport.

# %%
f1_weighted = f1_score(y_test.astype("str"),test_pred_class,average="weighted")
accuracy = accuracy_score(y_test.astype("str"),test_pred_class)
update_reporting_line(model_id,{
    "test_f1_score":f1_weighted,
    "test_accuracy":accuracy
})

print("f1_score on test dataset=%.4f" % f1_weighted)
print("accuracy on test dataset=%.4f" % accuracy)
# Out:
# f1_score on test dataset=0.5308
# accuracy on test dataset=0.5281

# %% [markdown]
# On regagne encore 0.02 par rapport à la modélisation précédente.

# %% [markdown]
# Récupérons l'historique d'entraînement complet grâce à **get_full_training_history** qu'on va enregistrer. Puis, affichons deux graphiques :
#
# * L'évolution de l'accuracy et du score F1 en fonction des époques.
# * L'évolution des indicateurs de perte **loss** et **val_loss**.

# %%
history = get_full_training_history(model_id,training_history)
if history != None:
  save_training_history(model_id,history)
  #to avoid concat of same history when re-executing this cell
  training_history = None
  plot_training_history(history)

# %% [markdown]
# L'écart entre les courbes d'entraînement et de validation se resserre progressivement. À partir de l'époque 4, elles sont au coude à coude pour se croiser à l'époque 7, signe que l'overfitting reprend. Heureusement, le **f1-score** le plus élevé est atteint à l'époque 6. C'est donc ce modèle que nous avons enregistré.

# %% [markdown]
# On va maintenant afficher le rapport de classification qui va nous donner une vision détaillée par classe des scores de prédiction.

# %%
print(classification_report(y_test.astype("str"),test_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#           10       0.41      0.29      0.34       311
#         1140       0.51      0.61      0.56       267
#         1160       0.83      0.88      0.85       396
#         1180       0.24      0.41      0.30        76
#         1280       0.55      0.24      0.34       487
#         1281       0.29      0.22      0.25       207
#         1300       0.56      0.66      0.61       505
#         1301       0.43      0.68      0.53        81
#         1302       0.33      0.39      0.36       249
#         1320       0.59      0.30      0.40       324
#         1560       0.68      0.45      0.54       507
#         1920       0.73      0.81      0.77       431
#         1940       0.30      0.78      0.44        81
#         2060       0.40      0.50      0.45       499
#         2220       0.21      0.51      0.30        82
#         2280       0.60      0.67      0.63       476
#         2403       0.68      0.44      0.53       477
#         2462       0.56      0.44      0.49       142
#         2522       0.70      0.54      0.61       499
#         2582       0.39      0.38      0.39       259
#         2583       0.87      0.56      0.68      1021
#         2585       0.27      0.47      0.34       250
#         2705       0.40      0.78      0.53       276
#         2905       0.37      0.68      0.48        87
#           40       0.45      0.49      0.47       251
#           50       0.32      0.44      0.37       168
#           60       0.46      0.71      0.56        83
#
#     accuracy                           0.53      8492
#    macro avg       0.49      0.53      0.49      8492
# weighted avg       0.57      0.53      0.53      8492

# %% [markdown]
# Comparé au rapport du modèle 331, on observe une baisse des f1-score par classes bien qu'il restent à un niveau acceptable pour notre tâche.

# %% [markdown]
# Affichons la matrice de confusion sous forme de heatmap pour plus de lisibilité.

# %%
cm = pd.crosstab(y_test.astype("str"),test_pred_class,rownames=["réel"],colnames=["prédit"])
plot_confusion_matrix(np.array(cm))

# %% [markdown]
# Attendons, les prochaines modélisations pour commenter la matrice

# %% [markdown]
# ## Résumé

# %% [markdown]
# Nous avons atteint la fin de l'évaluation de cette modélisation. Affichons le rapport du modèle.

# %%
reporting_df.loc[model_id].T
# Out:
# model_name                                                          Modèle 3.4.3
# dataset_source                 output/data-preprocessing-resampling/df_{train...
# dataset_resampled                                                           True
# image_dataset_source             output/data-preprocessing-images/images_pre.zip
# image_dataset_zoomed                                                        True
# train_size                                                              109566.0
# image_size                                                                 224.0
# image_color_rgb                                                             True
# batch_size                                                                  32.0
# image_data_generator_params    {'preprocessing_function': 'preprocess_input',...
# start_lr                                                                   0.001
# last_lr                                                                    0.001
# optimizer                                                                   adam
# target_epochs                                                               20.0
# last_epoch                                                                   8.0
# fit_complete                                                                True
# f1_score                                                                0.521459
# val_f1_score                                                            0.529464
# test_f1_score                                                           0.530819
# accuracy                                                                0.525681
# val_accuracy                                                            0.523821
# test_accuracy                                                           0.528144
# loss                                                                    1.601717
# val_loss                                                                1.634477
# remarks                         early_stopping plus agressif + dropout_rate=0.30
# Name: 343, dtype: object

# %% [markdown]
# # Modélisation 5.1

# %% [markdown]
# On va maintenant tenter d'ajuster _au plus près_ les poids du modèle entraîné dans la section 4. Pour cela, on va poursuivre son entraînement mais en dégelant les 4 dernières couches du modèle **VGG16**. On espère ainsi améliorer un peu la spécificité de l'extraction de features qui devrait être mieux adaptée à notre tâche de classification et obtenir un meilleur f1 score.

# %%
model_id = 351

# %% [markdown]
# ## Import des données

# %% [markdown]
# On réutilise les données importées dans la modélisation 1

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# On réutilise le preprocessing de la modélisation 2

# %% [markdown]
# ## Initialisation du rapport de modèle

# %% [markdown]
# Si un fichier **model_reporting.csv** existe, on le charge. Autrement, on en crée un nouveau.

# %%
Path(output_dir).mkdir(parents=True, exist_ok=True)
try:
  reporting_df = load_reporting_df()
  print("loaded ",output_dir+"/model_reporting.csv")
except FileNotFoundError:
  reporting_df = create_reporting_df()
  print(output_dir+"/model_reporting.csv","not found. creating one")
# Out:
# loaded  output/data-modeling-images-3/model_reporting.csv

# %%
reporting_df.head()
# Out:
#              model_name                                     dataset_source  \
# model_id
# 0         Example model            output/data-exploration/X_train_pre.csv
# 311          Modèle 3.1  output/data-preprocessing-resampling/df_{train...
# 321          Modèle 3.2  output/data-preprocessing-resampling/df_{train...
# 331          Modèle 3.3  output/data-preprocessing-resampling/df_{train...
# 341        Modèle 3.4.1  output/data-preprocessing-resampling/df_{train...
#
#           dataset_resampled                             image_dataset_source  \
# model_id
# 0                     False                                  data/images.zip
# 311                    True  output/data-preprocessing-images/images_pre.zip
# 321                    True  output/data-preprocessing-images/images_pre.zip
# 331                    True  output/data-preprocessing-images/images_pre.zip
# 341                    True  output/data-preprocessing-images/images_pre.zip
#
#           image_dataset_zoomed  train_size  image_size  image_color_rgb  \
# model_id
# 0                        False     42458.0       300.0             True
# 311                       True     21913.0       224.0             True
# 321                       True    109566.0       224.0             True
# 331                       True    109566.0       224.0             True
# 341                       True    109566.0       224.0             True
#
#           batch_size                        image_data_generator_params  ...  \
# model_id                                                                 ...
# 0               32.0  {'rescale': 0.00392156862745098, 'shear_range'...  ...
# 311             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 321             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 331             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 341             32.0  {'preprocessing_function': 'preprocess_input',...  ...
#
#           fit_complete  f1_score val_f1_score  test_f1_score  accuracy  \
# model_id
# 0                 True  0.420000     0.370000       0.350000  0.570000
# 311               True  0.552243     0.520430       0.514401  0.558103
# 321               True  0.665658     0.561671       0.556558  0.669275
# 331               True  0.739655     0.601403       0.601500  0.742927
# 341               True  0.415287     0.483479       0.492511  0.421559
#
#           val_accuracy  test_accuracy      loss  val_loss  \
# model_id
# 0             0.390000       0.410000  1.567000  2.657000
# 311           0.516927       0.515191  1.433475  1.707712
# 321           0.552675       0.552991  1.067026  1.611750
# 331           0.597656       0.598681  0.806426  1.479870
# 341           0.472641       0.480217  1.990221  1.791615
#
#                                                     remarks
# model_id
# 0         Ceci n'est pas un vrai modèle. C'est juste un ...
# 311                                                     NaN
# 321                                                     NaN
# 331       4 dernière couches de VGG16 repassées à traina...
# 341         early_stopping plus agressif + dropout_rate=0.5
#
# [5 rows x 25 columns]

# %% [markdown]
# Ajoutons une ligne correspondant à notre modèle et commençons à renseigner ses informations.

# %%
add_reporting_line(model_id,"Modèle 3.5.1")

# %% [markdown]
# On peut déjà renseigner les informations sur les données sources qu'on utilise.

# %%
update_reporting_line(model_id,{
    "dataset_source": "output/data-preprocessing-resampling/df_{train,val,test}.zip",
    "dataset_resampled": True,
    "image_dataset_source" : "output/data-preprocessing-images/images_pre.zip",
    "image_dataset_zoomed" : True,
    "train_size": len(X_train),
})

# %% [markdown]
# ## Générateurs d'images

# %% [markdown]
# Dans cette section, nous allons créer les générateurs qui vont fournir au modèle les images.

# %% [markdown]
# On réutilise les mêmes générateurs que lors de la modélisation 4

# %%
update_reporting_line(model_id, {
    "image_data_generator_params" : {
      "preprocessing_function":"preprocess_input",
      "rotation_range":20,
      "width_shift_range":0.2,
      "height_shift_range":0.2,
      "shear_range":5,
      "zoom_range":0.1,
      "horizontal_flip":True,
      "vertical_flip":False,
      "fill_mode":'nearest'
      }
})


update_reporting_line(model_id, {
    "batch_size":batch_size,
    "image_size": target_img_size[0],
    "image_color_rgb": True
})

train_generator = train_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_train['imagefile'],"prdtypecode": y_train.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras
)
# Out:
# Found 109566 validated image filenames belonging to 27 classes.

# %%
validation_generator = validation_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_validation['imagefile'],"prdtypecode": y_validation.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras
)
# Out:
# Found 8492 validated image filenames belonging to 27 classes.

# %%
test_generator = test_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_test['imagefile'],"prdtypecode": y_test.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras,
    shuffle=False
)
# Out:
# Found 8492 validated image filenames belonging to 27 classes.

# %% [markdown]
# ## Création du modèle

# %% [markdown]
# S'il n'y a pas encore de modèle enregistré, on récupère le meilleur modèle de la section 4 en veillant à repasser la propriété **trainable** des 4 dernieres couches de **VGG16** à **true**. On choisit d'utiliser un taux d'apprentissage divisé par 10 de 0.0001, pour tenter d'ajuster au plus près les poids.

# %%
model = load_saved_model(model_id)
start_lr = 0.0001
if model == None:
  print("re-load model 343")
  model = load_saved_model(343)
  vgg = model.layers[0]
  for layer in vgg.layers[-4:]:
    layer.trainable = True
  model.compile(
      optimizer=Adam(learning_rate=start_lr),
      loss='categorical_crossentropy',
      metrics=['accuracy',w_f1_score]
  )
  update_reporting_line(model_id,{
      "start_lr": start_lr,
      "optimizer": "adam",
      "remarks": "4 dernière couches de VGG16 repassées à trainable=True + basé sur modèle 343"
  })
else:
  print("re-loaded model "+str(model_id))

model.summary()
# Out:
# Load previous model from output/data-modeling-images-3/model-351.keras
# re-loaded model 351
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 27)                13851
#
# =================================================================
# Total params: 15778651 (60.19 MB)
# Trainable params: 8143387 (31.06 MB)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________

# %% [markdown]
# ## Entraînement du modèle

# %% [markdown]
# On procède à l'entraînement du modèle uniquement si le rapport nous indique que son entraînement n'est pas fini (colonne **fit_complete**).
#
# Dans le cas de la reprise d'un entraînement interrompu, on reprend l'entraînement pour le nombre d'époques qu'il reste à accomplir pour atteindre le nombre d'époques visé (**target_epochs**).
#
# Une fois l'entraînement terminé, on passe **fit_complete** à **True**.
#
# Les métriques sur la progression de l'entraînement ainsi que les meilleurs modèles sont récoltées et enregistrées dans la callback **LogBest**.

# %%
target_epochs = 20
if not get_reporting_value(model_id,"fit_complete",False):
  update_reporting_line(model_id,{
      "target_epochs": target_epochs
  })
  training_history = model.fit(
      train_generator,
      validation_data=validation_generator,
      steps_per_epoch=train_generator.samples // batch_size,
      validation_steps = validation_generator.samples // batch_size,
      epochs=target_epochs - int(get_reporting_value(model_id,"last_epoch",0)),
      verbose=1,
      callbacks=[LogBest(model_id),earlier_stopping]
  )
  update_reporting_line(model_id,{"fit_complete":True})
else:
  print("No need to train model")
  training_history = None
# Out:
# No need to train model

# %% [markdown]
# ## Évaluation du modèle

# %% [markdown]
# Si un entraînement a eu lieu au cours de cette exécution du notebook, on recharge le meilleur modèle qu'on a trouvé.

# %%
if training_history != None:
  #if fit wad called, make sure to load best saved model, otherwise it's already loaded
  model = load_saved_model(model_id)

# %% [markdown]
# On teste le modèle sur l'ensemble de test.

# %%
test_pred = model.predict(test_generator,verbose=1)
# Out:
# 266/266 [==============================] - 45s 171ms/step

# %% [markdown]
# On doit convertir le résultat de **predict** depuis le format renvoyé par Keras, qui est une matrice de probabilités avec les classes en colonnes et les observations du jeu de test en lignes, en un tableau à 1 dimension contenant les classes prédites pour chaque observation.
#
# Pour cela, on extrait pour chaque observation l'index de la probabilité maximale de prédiction. On utilise ensuite cet index pour retrouver la classe correspondante dans **classes_keras**, la liste des classes telle qu'on la fournit à Keras.

# %%
test_pred_class = np.argmax(test_pred,axis=1)
test_pred_class = [classes_keras[c] for c in test_pred_class]

# %% [markdown]
# À partir des classes prédites et des observations réelles, on calcule le score F1 ainsi que l'accuracy de notre modèle, toujours sur le jeu de test.
#
# On enregistre ces informations dans le rapport.

# %%
f1_weighted = f1_score(y_test.astype("str"),test_pred_class,average="weighted")
accuracy = accuracy_score(y_test.astype("str"),test_pred_class)
update_reporting_line(model_id,{
    "test_f1_score":f1_weighted,
    "test_accuracy":accuracy
})

print("f1_score on test dataset=%.4f" % f1_weighted)
print("accuracy on test dataset=%.4f" % accuracy)
# Out:
# f1_score on test dataset=0.5831
# accuracy on test dataset=0.5777

# %% [markdown]
# On atteint à nouveau des performances qui se rapprochent de notre précédent record de 0.60.

# %% [markdown]
# Récupérons l'historique d'entraînement complet grâce à **get_full_training_history** qu'on va enregistrer. Puis, affichons deux graphiques :
#
# * L'évolution de l'accuracy et du score F1 en fonction des époques.
# * L'évolution des indicateurs de perte **loss** et **val_loss**.

# %%
history = get_full_training_history(model_id,training_history)
if history != None:
  save_training_history(model_id,history)
  #to avoid concat of same history when re-executing this cell
  training_history = None
  plot_training_history(history)

# %% [markdown]
# Sur le graphique de gauche, les courbes de validation passent en dessous de celles d'entraînement à l'époque 2. On voit toutefois qu'elles continuent de croître à un rythme proche jusqu'à l'époque 3 pour ensuite ralentir tout en conservant tout de même une tendance croissante nette.
#
# Doit-on encore considérer cela comme de l'overfitting ? C'est la question qu'on se pose, car :
# - La généralisation du modèle progresse encore, mais à un rythme moins soutenu que son entraînement.
# - On a tout de même une double confirmation des scores de généralisation sur les ensembles de validation et de test qui ont des f1-scores quasi identiques. Cela représente quand même un test sur 16 000 observations.
#
# Cette question reste ouverte. Nous tenterons d'y répondre avant la fin de ce notebook.

# %% [markdown]
# On va maintenant afficher le rapport de classification qui va nous donner une vision détaillée par classe des scores de prédiction.

# %%
print(classification_report(y_test.astype("str"),test_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#           10       0.43      0.57      0.49       311
#         1140       0.61      0.57      0.59       267
#         1160       0.93      0.88      0.91       396
#         1180       0.22      0.47      0.30        76
#         1280       0.64      0.21      0.31       487
#         1281       0.29      0.41      0.34       207
#         1300       0.65      0.71      0.68       505
#         1301       0.61      0.62      0.61        81
#         1302       0.31      0.51      0.39       249
#         1320       0.46      0.49      0.47       324
#         1560       0.76      0.41      0.53       507
#         1920       0.67      0.85      0.75       431
#         1940       0.47      0.74      0.58        81
#         2060       0.47      0.41      0.44       499
#         2220       0.28      0.38      0.32        82
#         2280       0.73      0.72      0.72       476
#         2403       0.78      0.47      0.58       477
#         2462       0.56      0.47      0.51       142
#         2522       0.73      0.59      0.65       499
#         2582       0.33      0.51      0.40       259
#         2583       0.89      0.67      0.77      1021
#         2585       0.29      0.49      0.37       250
#         2705       0.62      0.72      0.67       276
#         2905       0.59      0.86      0.70        87
#           40       0.62      0.58      0.60       251
#           50       0.34      0.49      0.40       168
#           60       0.43      0.77      0.55        83
#
#     accuracy                           0.58      8492
#    macro avg       0.54      0.58      0.54      8492
# weighted avg       0.63      0.58      0.58      8492

# %% [markdown]
# On retrouve des scores proches de ceux obtenus en 3.1

# %% [markdown]
# Affichons la matrice de confusion sous forme de heatmap pour plus de lisibilité.

# %%
cm = pd.crosstab(y_test.astype("str"),test_pred_class,rownames=["réel"],colnames=["prédit"])
plot_confusion_matrix(np.array(cm))

# %% [markdown]
# Idem pour la matrice de confusion, très proche de celle obtenue en 3.1

# %% [markdown]
# ## Résumé

# %% [markdown]
# Nous avons atteint la fin de l'évaluation de cette modélisation. Affichons le rapport du modèle.

# %%
reporting_df.loc[model_id].T
# Out:
# model_name                                                          Modèle 3.5.1
# dataset_source                 output/data-preprocessing-resampling/df_{train...
# dataset_resampled                                                           True
# image_dataset_source             output/data-preprocessing-images/images_pre.zip
# image_dataset_zoomed                                                        True
# train_size                                                              109566.0
# image_size                                                                 224.0
# image_color_rgb                                                             True
# batch_size                                                                  32.0
# image_data_generator_params    {'preprocessing_function': 'preprocess_input',...
# start_lr                                                                  0.0001
# last_lr                                                                   0.0001
# optimizer                                                                   adam
# target_epochs                                                               20.0
# last_epoch                                                                   8.0
# fit_complete                                                                True
# f1_score                                                                0.660953
# val_f1_score                                                            0.582362
# test_f1_score                                                           0.583075
# accuracy                                                                0.664643
# val_accuracy                                                            0.573113
# test_accuracy                                                            0.57772
# loss                                                                     1.09201
# val_loss                                                                1.492979
# remarks                        4 dernière couches de VGG16 repassées à traina...
# Name: 351, dtype: object

# %% [markdown]
# # Modélisation 5.2

# %% [markdown]
# Lors de la modélisation précédente, nous avons réussi à remonter le f1-score jusqu'à un niveau proche de notre maximum actuel de 0.60. Un doute subsiste concernant la présence d'un véritable overfitting ou non. Nous allons donc réitérer l'entraînement précédent en limitant le nombre d'époques à 3 afin de pouvoir enregistrer le modèle sans risque d'overfitting, tout en maximisant sa performance.
#
# On décidera de quel modèle semble le meilleur in fine dans la conclusion de ce notebook.

# %%
model_id = 352

# %% [markdown]
# ## Import des données

# %% [markdown]
# On réutilise les données importées dans la modélisation 1

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# On réutilise le preprocessing de la modélisation 2

# %% [markdown]
# ## Initialisation du rapport de modèle

# %% [markdown]
# Si un fichier **model_reporting.csv** existe, on le charge. Autrement, on en crée un nouveau.

# %%
Path(output_dir).mkdir(parents=True, exist_ok=True)
try:
  reporting_df = load_reporting_df()
  print("loaded ",output_dir+"/model_reporting.csv")
except FileNotFoundError:
  reporting_df = create_reporting_df()
  print(output_dir+"/model_reporting.csv","not found. creating one")
# Out:
# loaded  output/data-modeling-images-3/model_reporting.csv

# %%
reporting_df.head()
# Out:
#              model_name                                     dataset_source  \
# model_id
# 0         Example model            output/data-exploration/X_train_pre.csv
# 311          Modèle 3.1  output/data-preprocessing-resampling/df_{train...
# 321          Modèle 3.2  output/data-preprocessing-resampling/df_{train...
# 331          Modèle 3.3  output/data-preprocessing-resampling/df_{train...
# 341        Modèle 3.4.1  output/data-preprocessing-resampling/df_{train...
#
#           dataset_resampled                             image_dataset_source  \
# model_id
# 0                     False                                  data/images.zip
# 311                    True  output/data-preprocessing-images/images_pre.zip
# 321                    True  output/data-preprocessing-images/images_pre.zip
# 331                    True  output/data-preprocessing-images/images_pre.zip
# 341                    True  output/data-preprocessing-images/images_pre.zip
#
#           image_dataset_zoomed  train_size  image_size  image_color_rgb  \
# model_id
# 0                        False     42458.0       300.0             True
# 311                       True     21913.0       224.0             True
# 321                       True    109566.0       224.0             True
# 331                       True    109566.0       224.0             True
# 341                       True    109566.0       224.0             True
#
#           batch_size                        image_data_generator_params  ...  \
# model_id                                                                 ...
# 0               32.0  {'rescale': 0.00392156862745098, 'shear_range'...  ...
# 311             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 321             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 331             64.0  {'preprocessing_function': 'preprocess_input',...  ...
# 341             32.0  {'preprocessing_function': 'preprocess_input',...  ...
#
#           fit_complete  f1_score val_f1_score  test_f1_score  accuracy  \
# model_id
# 0                 True  0.420000     0.370000       0.350000  0.570000
# 311               True  0.552243     0.520430       0.514401  0.558103
# 321               True  0.665658     0.561671       0.556558  0.669275
# 331               True  0.739655     0.601403       0.601500  0.742927
# 341               True  0.415287     0.483479       0.492511  0.421559
#
#           val_accuracy  test_accuracy      loss  val_loss  \
# model_id
# 0             0.390000       0.410000  1.567000  2.657000
# 311           0.516927       0.515191  1.433475  1.707712
# 321           0.552675       0.552991  1.067026  1.611750
# 331           0.597656       0.598681  0.806426  1.479870
# 341           0.472641       0.480217  1.990221  1.791615
#
#                                                     remarks
# model_id
# 0         Ceci n'est pas un vrai modèle. C'est juste un ...
# 311                                                     NaN
# 321                                                     NaN
# 331       4 dernière couches de VGG16 repassées à traina...
# 341         early_stopping plus agressif + dropout_rate=0.5
#
# [5 rows x 25 columns]

# %% [markdown]
# Ajoutons une ligne correspondant à notre modèle et commençons à renseigner ses informations.

# %%
add_reporting_line(model_id,"Modèle 3.5.2")

# %% [markdown]
# On peut déjà renseigner les informations sur les données sources qu'on utilise.

# %%
update_reporting_line(model_id,{
    "dataset_source": "output/data-preprocessing-resampling/df_{train,val,test}.zip",
    "dataset_resampled": True,
    "image_dataset_source" : "output/data-preprocessing-images/images_pre.zip",
    "image_dataset_zoomed" : True,
    "train_size": len(X_train),
})

# %% [markdown]
# ## Générateurs d'images

# %% [markdown]
# Dans cette section, nous allons créer les générateurs qui vont fournir au modèle les images.

# %% [markdown]
# On réutilise les mêmes générateurs que lors de la modélisation 4

# %%
update_reporting_line(model_id, {
    "image_data_generator_params" : {
      "preprocessing_function":"preprocess_input",
      "rotation_range":20,
      "width_shift_range":0.2,
      "height_shift_range":0.2,
      "shear_range":5,
      "zoom_range":0.1,
      "horizontal_flip":True,
      "vertical_flip":False,
      "fill_mode":'nearest'
      }
})


update_reporting_line(model_id, {
    "batch_size":batch_size,
    "image_size": target_img_size[0],
    "image_color_rgb": True
})

train_generator = train_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_train['imagefile'],"prdtypecode": y_train.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras
)
# Out:
# Found 109566 validated image filenames belonging to 27 classes.

# %%
validation_generator = validation_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_validation['imagefile'],"prdtypecode": y_validation.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras
)
# Out:
# Found 8492 validated image filenames belonging to 27 classes.

# %%
test_generator = test_data_generator.flow_from_dataframe(
    dataframe=pd.DataFrame({"imagefile": X_test['imagefile'],"prdtypecode": y_test.astype("str")}),
    x_col="imagefile",
    y_col="prdtypecode",
    directory=image_path,
    target_size=target_img_size[:2],
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode="categorical",
    classes=classes_keras,
    shuffle=False
)
# Out:
# Found 8492 validated image filenames belonging to 27 classes.

# %% [markdown]
# ## Création du modèle

# %% [markdown]
# S'il n'y a pas encore de modèle enregistré, on récupère le meilleu modèle de la section 2 en veillant à repasser la propriété **trainable** des 4 dernieres couches de **VGG16** à **true**. On choisit d'utiliser un taux d'apprentissage divisé par 10 de 0.0001 cette fois-ci, pour tenter d'ajuster au plus près les poids.

# %%
model = load_saved_model(model_id)
start_lr = 0.0001
if model == None:
  print("re-load model 343")
  model = load_saved_model(343)
  vgg = model.layers[0]
  for layer in vgg.layers[-4:]:
    layer.trainable = True
  model.compile(
      optimizer=Adam(learning_rate=start_lr),
      loss='categorical_crossentropy',
      metrics=['accuracy',w_f1_score]
  )
  update_reporting_line(model_id,{
      "start_lr": start_lr,
      "optimizer": "adam",
      "remarks": "4 dernière couches de VGG16 repassées à trainable=True + basé sur modèle 343"
  })
else:
  print("re-loaded model "+str(model_id))

model.summary()
# Out:
# No previous model found at output/data-modeling-images-3/model-352.keras
# re-load model 343
# Load previous model from output/data-modeling-images-3/model-343.keras
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 27)                13851
#
# =================================================================
# Total params: 15778651 (60.19 MB)
# Trainable params: 8143387 (31.06 MB)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________

# %% [markdown]
# ## Entraînement du modèle

# %% [markdown]
# On procède à l'entraînement du modèle uniquement si le rapport nous indique que son entraînement n'est pas fini (colonne **fit_complete**).
#
# Dans le cas de la reprise d'un entraînement interrompu, on reprend l'entraînement pour le nombre d'époques qu'il reste à accomplir pour atteindre le nombre d'époques visé (**target_epochs**) qu'on passe à 3 comme annoncé dans l'introduction.
#
# Une fois l'entraînement terminé, on passe **fit_complete** à **True**.
#
# Les métriques sur la progression de l'entraînement ainsi que les meilleurs modèles sont récoltées et enregistrées dans la callback **LogBest**.

# %%
target_epochs = 3
if not get_reporting_value(model_id,"fit_complete",False):
  update_reporting_line(model_id,{
      "target_epochs": target_epochs
  })
  training_history = model.fit(
      train_generator,
      validation_data=validation_generator,
      steps_per_epoch=train_generator.samples // batch_size,
      validation_steps = validation_generator.samples // batch_size,
      epochs=target_epochs - int(get_reporting_value(model_id,"last_epoch",0)),
      verbose=1,
      callbacks=[LogBest(model_id),earlier_stopping]
  )
  update_reporting_line(model_id,{"fit_complete":True})
else:
  print("No need to train model")
  training_history = None
# Out:
# Epoch 1/3
# 3423/3423 [==============================] - ETA: 0s - loss: 1.7557 - accuracy: 0.4879 - w_f1_score: 0.4808
# Found better model with val_f1_score=0.54
# save model  352 to  output/data-modeling-images-3/model-352.keras
# 3423/3423 [==============================] - 2207s 643ms/step - loss: 1.7557 - accuracy: 0.4879 - w_f1_score: 0.4808 - val_loss: 1.6050 - val_accuracy: 0.5242 - val_w_f1_score: 0.5356
# Epoch 2/3
# 3423/3423 [==============================] - ETA: 0s - loss: 1.5052 - accuracy: 0.5514 - w_f1_score: 0.5460
# Found better model with val_f1_score=0.55
# save model  352 to  output/data-modeling-images-3/model-352.keras
# 3423/3423 [==============================] - 1928s 563ms/step - loss: 1.5052 - accuracy: 0.5514 - w_f1_score: 0.5460 - val_loss: 1.5221 - val_accuracy: 0.5413 - val_w_f1_score: 0.5485
# Epoch 3/3
# 3423/3423 [==============================] - 1843s 539ms/step - loss: 1.3889 - accuracy: 0.5847 - w_f1_score: 0.5804 - val_loss: 1.5722 - val_accuracy: 0.5327 - val_w_f1_score: 0.5421

# %% [markdown]
# ## Évaluation du modèle

# %% [markdown]
# Si un entraînement a eu lieu au cours de cette exécution du notebook, on recharge le meilleur modèle qu'on a trouvé.

# %%
if training_history != None:
  #if fit wad called, make sure to load best saved model, otherwise it's already loaded
  model = load_saved_model(model_id)
# Out:
# Load previous model from output/data-modeling-images-3/model-352.keras

# %% [markdown]
# On teste le modèle sur l'ensemble de test.

# %%
test_pred = model.predict(test_generator,verbose=1)
# Out:
# 266/266 [==============================] - 44s 165ms/step

# %% [markdown]
# On doit convertir le résultat de **predict** depuis le format renvoyé par Keras, qui est une matrice de probabilités avec les classes en colonnes et les observations du jeu de test en lignes, en un tableau à 1 dimension contenant les classes prédites pour chaque observation.
#
# Pour cela, on extrait pour chaque observation l'index de la probabilité maximale de prédiction. On utilise ensuite cet index pour retrouver la classe correspondante dans **classes_keras**, la liste des classes telle qu'on la fournit à Keras.

# %%
test_pred_class = np.argmax(test_pred,axis=1)
test_pred_class = [classes_keras[c] for c in test_pred_class]

# %% [markdown]
# À partir des classes prédites et des observations réelles, on calcule le score F1 ainsi que l'accuracy de notre modèle, toujours sur le jeu de test.
#
# On enregistre ces informations dans le rapport.

# %%
f1_weighted = f1_score(y_test.astype("str"),test_pred_class,average="weighted")
accuracy = accuracy_score(y_test.astype("str"),test_pred_class)
update_reporting_line(model_id,{
    "test_f1_score":f1_weighted,
    "test_accuracy":accuracy
})

print("f1_score on test dataset=%.4f" % f1_weighted)
print("accuracy on test dataset=%.4f" % accuracy)
# Out:
# f1_score on test dataset=0.5531
# accuracy on test dataset=0.5492

# %% [markdown]
# On atteint un **f1-score** de 0.55, qui semble parfaitement aligné avec le score obtenu par le vainqueur du challenge Rakuten. C'est peut-être le compromis qu'on cherche entre performance et overfitting.

# %% [markdown]
# Récupérons l'historique d'entraînement complet grâce à **get_full_training_history** qu'on va enregistrer. Puis, affichons deux graphiques :
#
# * L'évolution de l'accuracy et du score F1 en fonction des époques.
# * L'évolution des indicateurs de perte **loss** et **val_loss**.

# %%
history = get_full_training_history(model_id,training_history)
if history != None:
  save_training_history(model_id,history)
  #to avoid concat of same history when re-executing this cell
  training_history = None
  plot_training_history(history)

# %% [markdown]
# On observe que les courbes de validation et d'entraînement se croisent à la deuxième époque, époque à laquelle on atteint le **f1-score** le plus haut. On peut donc affirmer que le meilleur modèle enregistré ne devrait souffrir d'aucun overfitting.

# %% [markdown]
# On va maintenant afficher le rapport de classification qui va nous donner une vision détaillée par classe des scores de prédiction.

# %%
print(classification_report(y_test.astype("str"),test_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#           10       0.48      0.39      0.43       311
#         1140       0.53      0.58      0.56       267
#         1160       0.89      0.88      0.88       396
#         1180       0.26      0.39      0.31        76
#         1280       0.56      0.22      0.32       487
#         1281       0.27      0.34      0.30       207
#         1300       0.56      0.68      0.61       505
#         1301       0.65      0.52      0.58        81
#         1302       0.26      0.54      0.35       249
#         1320       0.42      0.38      0.40       324
#         1560       0.63      0.40      0.49       507
#         1920       0.65      0.85      0.74       431
#         1940       0.47      0.68      0.56        81
#         2060       0.48      0.41      0.44       499
#         2220       0.29      0.39      0.34        82
#         2280       0.66      0.73      0.69       476
#         2403       0.78      0.52      0.62       477
#         2462       0.53      0.49      0.51       142
#         2522       0.75      0.56      0.64       499
#         2582       0.39      0.34      0.36       259
#         2583       0.86      0.61      0.71      1021
#         2585       0.25      0.42      0.31       250
#         2705       0.52      0.79      0.63       276
#         2905       0.48      0.82      0.60        87
#           40       0.57      0.55      0.56       251
#           50       0.27      0.46      0.34       168
#           60       0.48      0.73      0.58        83
#
#     accuracy                           0.55      8492
#    macro avg       0.52      0.54      0.51      8492
# weighted avg       0.59      0.55      0.55      8492

# %% [markdown]
# Affichons la matrice de confusion sous forme de heatmap pour plus de lisibilité.

# %%
cm = pd.crosstab(y_test.astype("str"),test_pred_class,rownames=["réel"],colnames=["prédit"])
plot_confusion_matrix(np.array(cm))

# %% [markdown]
# ## Résumé

# %% [markdown]
# Nous avons atteint la fin de l'évaluation de cette modélisation. Affichons le rapport du modèle.

# %%
reporting_df.loc[model_id].T
# Out:
# model_name                                                          Modèle 3.5.2
# dataset_source                 output/data-preprocessing-resampling/df_{train...
# dataset_resampled                                                           True
# image_dataset_source             output/data-preprocessing-images/images_pre.zip
# image_dataset_zoomed                                                        True
# train_size                                                              109566.0
# image_size                                                                 224.0
# image_color_rgb                                                             True
# batch_size                                                                  32.0
# image_data_generator_params    {'preprocessing_function': 'preprocess_input',...
# start_lr                                                                  0.0001
# last_lr                                                                   0.0001
# optimizer                                                                   adam
# target_epochs                                                                3.0
# last_epoch                                                                   3.0
# fit_complete                                                                True
# f1_score                                                                0.545998
# val_f1_score                                                            0.548519
# test_f1_score                                                           0.553074
# accuracy                                                                0.551354
# val_accuracy                                                            0.541274
# test_accuracy                                                           0.549223
# loss                                                                    1.505246
# val_loss                                                                1.522122
# remarks                        4 dernière couches de VGG16 repassées à traina...
# Name: 352, dtype: object

# %% [markdown]
# # Comparaison de tous les modèles du notebook

# %% [markdown]
# Comparons maintenant tous les modèles du notebooks.

# %%
model_comparison_cols = ["model_name","dataset_resampled","image_dataset_zoomed",
        "train_size","image_size","batch_size",
        "accuracy","f1_score","val_accuracy","val_f1_score","test_f1_score","test_accuracy",
          "loss","val_loss"]
display(reporting_df.loc[[311,321,331,341,342,343,351,352],model_comparison_cols].T)
# Out:
# model_id                     311         321         331           341  \
# model_name            Modèle 3.1  Modèle 3.2  Modèle 3.3  Modèle 3.4.1
# dataset_resampled           True        True        True          True
# image_dataset_zoomed        True        True        True          True
# train_size               21913.0    109566.0    109566.0      109566.0
# image_size                 224.0       224.0       224.0         224.0
# batch_size                  64.0        64.0        64.0          32.0
# accuracy                0.558103    0.669275    0.742927      0.421559
# f1_score                0.552243    0.665658    0.739655      0.415287
# val_accuracy            0.516927    0.552675    0.597656      0.472641
# val_f1_score             0.52043    0.561671    0.601403      0.483479
# test_f1_score           0.514401    0.556558      0.6015      0.492511
# test_accuracy           0.515191    0.552991    0.598681      0.480217
# loss                    1.433475    1.067026    0.806426      1.990221
# val_loss                1.707712     1.61175     1.47987      1.791615
#
# model_id                       342           343           351           352
# model_name            Modèle 3.4.2  Modèle 3.4.3  Modèle 3.5.1  Modèle 3.5.2
# dataset_resampled             True          True          True          True
# image_dataset_zoomed          True          True          True          True
# train_size                109566.0      109566.0      109566.0      109566.0
# image_size                   224.0         224.0         224.0         224.0
# batch_size                    32.0          32.0          32.0          32.0
# accuracy                  0.486169      0.525681      0.664643      0.551354
# f1_score                  0.481566      0.521459      0.660953      0.545998
# val_accuracy               0.50625      0.523821      0.573113      0.541274
# val_f1_score               0.51619      0.529464      0.582362      0.548519
# test_f1_score             0.512809      0.530819      0.583075      0.553074
# test_accuracy             0.506123      0.528144       0.57772      0.549223
# loss                      1.739799      1.601717       1.09201      1.505246
# val_loss                  1.648645      1.634477      1.492979      1.522122

# %% [markdown]
# # Conclusion

# %% [markdown]
# Ce notebook nous a permis d'explorer les avantages du transfer learning qui permet d'avoir rapidement un extracteur de features performant pour des images, accélérant ainsi drastiquement l'apprentissage d'un classifieur.
#
# Il est possible qu'on puisse avoir des performances correctes en investissant le temps et les ressources de calcul nécessaires à l'entraînement d'un CNN depuis le début. Cela représente toutefois un temps et un investissement qu'il paraît difficile de justifier dans un contexte d'entreprise, à moins que celle-ci soit vraiment tournée vers la recherche.
#
# Quant à la question du meilleur modèle qu'on retient, après des discussions avec notre mentor qui nous ont permis d'éclaircir la notion d'overfitting, nous avons résolu de retenir le modèle 331, c'est-à-dire celui qui atteint le f1-score maximum du notebook. En effet, la crainte de l'overfitting le concernant n'est pas justifiée pour les raisons qu'on exprime dans l'évaluation du modèle 5.1. Il est notable que malgré une séparation des courbes de validation et d'entraînement, le modèle continue de progresser en capacité de généralisation, même si la vitesse de progression reste inférieure à celle de la progression de l'apprentissage sur l'ensemble d'entraînement.
